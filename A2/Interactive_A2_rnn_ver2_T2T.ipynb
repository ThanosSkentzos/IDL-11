# %% [markdown]
#  <div style="text-align: right">   </div>
#  Introduction to Deep Learning (2024)
#
#  **Assignment 2 - Sequence processing using RNNs**
#  <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#  # Introduction
#
#  The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs).
#  Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
#  <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
#  In this assignment you will be working with three different kinds of models, based on input/output data modalities:
#
#  1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
#
#  2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
#
#  3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#  ### Description
#
#  Let us suppose that we want to develop a neural network that learns how to add or subtract
#
#  two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
#
#  ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
#
#  sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
#
#  we want to build a model that generalizes well - if the network can extract the underlying principles behind
#
#  the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
#
#  valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
#
#  2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
#
#  The example above describes a text-to-text sequence mapping scenario. However, we can also use different
#
#  modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
#
#  dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
#  *To work on this notebook you should create a copy of it.*

# %% [markdown]
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, LSTM, Flatten, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector, Conv2D, ConvLSTM2D # type: ignore

# %%
from scipy.ndimage import rotate


# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))
show_generated(generate_images(sign='-'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #5187
#
# X_text: "25-93" = y_text: "-68"
# ==================================================
# Query #4655
#
# X_text: "23-27" = y_text: "-4 "
# ==================================================
# Query #6779
#
# X_text: "33-89" = y_text: "-56"
# ==================================================
# Query #517
#
# X_text: "2-58 " = y_text: "-56"
# ==================================================
# Query #5757
#
# X_text: "28-78" = y_text: "-50"
# ==================================================
# Query #351
#
# X_text: "1-75 " = y_text: "-74"
# ==================================================
# Query #1371
#
# X_text: "6-85 " = y_text: "-79"
# ==================================================
# Query #2893
#
# X_text: "14-46" = y_text: "-32"
# ==================================================
# Query #6728
#
# X_text: "33+64" = y_text: "97 "
# ==================================================
# Query #353
#
# X_text: "1-76 " = y_text: "-75"

# %% [markdown]
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
#  ---
#
#  ## I. Text-to-text RNN model
#
#  The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
#  1. LSTM
#
#  2. TimeDistributed
#
#  3. RepeatVector
#
#  The code cell below explains each of these new components.
#
#  <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
def build_text2text_model():
    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. 
    # Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

# %%
## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)
import tensorflow.keras as keras # type: ignore
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split


data_percentage = [[80.0, 10.0, 10.0, 50], [50.0, 0.0, 50.0, 50], [25.0, 0.0, 75.0, 75], [10.0, 0.0, 90.0, 100]]

for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, random_state=42) 

    
    print(decode_labels(X_test[0]))
    print(decode_labels(y_test[0]))
    # Fit the model
    model = build_text2text_model()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',  # metric to monitor
            patience=10,          # number of epochs to wait for improvement
            restore_best_weights=True  # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    model.save(f'submission1_text_to_text.keras')

    data_history = pd.DataFrame(history.history)
    data_history.to_csv('text_to_text_history.csv')
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
    
    #to clear cache
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 53+25
# 78
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 256)               276480
#
#  repeat_vector_1 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_4 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed_6 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 2024-12-11 19:26:04.648579: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733963167.693966   37554 service.cc:146] XLA service 0x7f053d98f510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733963167.694001   37554 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# I0000 00:00:1733963167.694012   37554 service.cc:154]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-12-11 19:26:07.712957: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1733963168.012132   37554 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 500/500 [==============================] - 12s 11ms/step - loss: 1.7707 - accuracy: 0.3923 - val_loss: 1.4439 - val_accuracy: 0.4892
# Epoch 2/50
# 500/500 [==============================] - 5s 9ms/step - loss: 1.3443 - accuracy: 0.5122 - val_loss: 1.2044 - val_accuracy: 0.5752
# Epoch 3/50
# 500/500 [==============================] - 5s 9ms/step - loss: 1.1847 - accuracy: 0.5643 - val_loss: 1.1275 - val_accuracy: 0.5923
# Epoch 4/50
# 500/500 [==============================] - 4s 9ms/step - loss: 1.0925 - accuracy: 0.5962 - val_loss: 1.1455 - val_accuracy: 0.5647
# Epoch 5/50
# 500/500 [==============================] - 4s 9ms/step - loss: 1.0357 - accuracy: 0.6141 - val_loss: 1.0171 - val_accuracy: 0.6072
# Epoch 6/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.9779 - accuracy: 0.6330 - val_loss: 0.9423 - val_accuracy: 0.6433
# Epoch 7/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.9347 - accuracy: 0.6510 - val_loss: 0.9102 - val_accuracy: 0.6555
# Epoch 8/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.8959 - accuracy: 0.6635 - val_loss: 0.9204 - val_accuracy: 0.6435
# Epoch 9/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.8374 - accuracy: 0.6844 - val_loss: 0.8313 - val_accuracy: 0.6827
# Epoch 10/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.7523 - accuracy: 0.7176 - val_loss: 0.7130 - val_accuracy: 0.7385
# Epoch 11/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.6249 - accuracy: 0.7705 - val_loss: 0.5425 - val_accuracy: 0.8112
# Epoch 12/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.4740 - accuracy: 0.8376 - val_loss: 0.4096 - val_accuracy: 0.8680
# Epoch 13/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.3591 - accuracy: 0.8879 - val_loss: 0.3133 - val_accuracy: 0.9192
# Epoch 14/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.2696 - accuracy: 0.9274 - val_loss: 0.2539 - val_accuracy: 0.9235
# Epoch 15/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.2119 - accuracy: 0.9458 - val_loss: 0.3071 - val_accuracy: 0.8822
# Epoch 16/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1775 - accuracy: 0.9570 - val_loss: 0.1387 - val_accuracy: 0.9717
# Epoch 17/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.
ARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1881 - accuracy: 0.9603
# Epoch 81/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1823 - accuracy: 0.9638WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1816 - accuracy: 0.9637
# Epoch 82/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1651 - accuracy: 0.9677WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1657 - accuracy: 0.9673
# Epoch 83/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1729 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1755 - accuracy: 0.9638
# Epoch 84/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2253 - accuracy: 0.9363WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2251 - accuracy: 0.9365
# Epoch 85/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2659 - accuracy: 0.9168WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2648 - accuracy: 0.9170
# Epoch 86/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1927 - accuracy: 0.9513WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1925 - accuracy: 0.9513
# Epoch 87/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1499 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1497 - accuracy: 0.9712
# Epoch 88/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1331 - accuracy: 0.9782
# Epoch 89/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1164 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1165 - accuracy: 0.9845
# Epoch 90/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.9841WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1165 - accuracy: 0.9837
# Epoch 91/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1221 - accuracy: 0.9793WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1226 - accuracy: 0.9797
# Epoch 92/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.9768WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1226 - accuracy: 0.9763
# Epoch 93/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9862WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1056 - accuracy: 0.9863
# Epoch 94/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1034 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1040 - accuracy: 0.9863
# Epoch 95/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1200 - accuracy: 0.9768WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1207 - accuracy: 0.9767
# Epoch 96/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9466WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2004 - accuracy: 0.9465
# Epoch 97/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1931 - accuracy: 0.9484WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1921 - accuracy: 0.9487
# Epoch 98/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1301 - accuracy: 0.9743WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1299 - accuracy: 0.9743
# Epoch 99/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1087 - accuracy: 0.9822
# Epoch 100/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9904WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0807 - accuracy: 0.9905
# 563/563 [==============================] - 3s 4ms/step
# 63/63 [==============================] - 1s 4ms/step - loss: 0.0644 - accuracy: 0.9965
# Train Accuracy for text to text model: [0.06441336125135422, 0.9965000152587891]
# 563/563 [==============================] - 2s 4ms/step - loss: 0.8187 - accuracy: 0.7445
# Test Accuracy for text to text model: [0.818695068359375, 0.744518518447876]

# %% [markdown]
#  <div style="text-align: right">   </div>
#  Introduction to Deep Learning (2024)
#
#  **Assignment 2 - Sequence processing using RNNs**
#  <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#  # Introduction
#
#  The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs).
#  Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
#  <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
#  In this assignment you will be working with three different kinds of models, based on input/output data modalities:
#
#  1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
#
#  2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
#
#  3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#  ### Description
#
#  Let us suppose that we want to develop a neural network that learns how to add or subtract
#
#  two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
#
#  ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
#
#  sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
#
#  we want to build a model that generalizes well - if the network can extract the underlying principles behind
#
#  the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
#
#  valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
#
#  2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
#
#  The example above describes a text-to-text sequence mapping scenario. However, we can also use different
#
#  modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
#
#  dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
#  *To work on this notebook you should create a copy of it.*

# %% [markdown]
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, LSTM, Flatten, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector, Conv2D, ConvLSTM2D # type: ignore

# %%
from scipy.ndimage import rotate


# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))
show_generated(generate_images(sign='-'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=False)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=False)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #6997
#
# X_text: "34-98" = y_text: "-64"
# ==================================================
# Query #7180
#
# X_text: "35+90" = y_text: "125"
# ==================================================
# Query #9266
#
# X_text: "46+33" = y_text: " 79"
# ==================================================
# Query #1761
#
# X_text: " 8-80" = y_text: "-72"
# ==================================================
# Query #2777
#
# X_text: "13-88" = y_text: "-75"
# ==================================================
# Query #5087
#
# X_text: "25-43" = y_text: "-18"
# ==================================================
# Query #4788
#
# X_text: "23+94" = y_text: "117"
# ==================================================
# Query #93
#
# X_text: " 0-46" = y_text: "-46"
# ==================================================
# Query #5056
#
# X_text: "25+28" = y_text: " 53"
# ==================================================
# Query #3378
#
# X_text: "16+89" = y_text: "105"

# %% [markdown]
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
#  ---
#
#  ## I. Text-to-text RNN model
#
#  The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
#  1. LSTM
#
#  2. TimeDistributed
#
#  3. RepeatVector
#
#  The code cell below explains each of these new components.
#
#  <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
def build_text2text_model():
    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. 
    # Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

# %%
## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)
import tensorflow.keras as keras # type: ignore
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split


data_percentage = [[80.0, 10.0, 10.0, 50], [50.0, 0.0, 50.0, 50], [25.0, 0.0, 75.0, 75], [10.0, 0.0, 90.0, 100]]

for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, random_state=42) 

    
    print(decode_labels(X_test[0]))
    print(decode_labels(y_test[0]))
    # Fit the model
    model = build_text2text_model()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',  # metric to monitor
            patience=10,          # number of epochs to wait for improvement
            restore_best_weights=True  # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    model.save(f'submission1_text_to_text.keras')

    data_history = pd.DataFrame(history.history)
    data_history.to_csv('text_to_text_history.csv')
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
    
    #to clear cache
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 53+25
#  78
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 256)               276480
#
#  repeat_vector_5 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_12 (LSTM)              (None, 3, 256)            525312
#
#  time_distributed_10 (TimeD  (None, 3, 13)             3341
#  istributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] -
50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.0325 - val_accuracy: 0.9907
# Epoch 31/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.0176 - val_accuracy: 0.9955
# Epoch 32/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.0033 - val_accuracy: 0.9998
# Epoch 33/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9998
# Epoch 34/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0232 - accuracy: 0.9939 - val_loss: 0.2600 - val_accuracy: 0.9123
# Epoch 35/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0676 - accuracy: 0.9799 - val_loss: 0.0050 - val_accuracy: 0.9998
# Epoch 36/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9998
# Epoch 37/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9997
# Epoch 38/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0733 - accuracy: 0.9765 - val_loss: 0.0684 - val_accuracy: 0.9752
# Epoch 39/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0151 - accuracy: 0.9963 - val_loss: 0.0042 - val_accuracy: 0.9995
# Epoch 40/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9997
# Epoch 41/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9998
# Epoch 42/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 43/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1122 - val_accuracy: 0.9783
# Epoch 44/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0963 - accuracy: 0.9723 - val_loss: 0.0125 - val_accuracy: 0.9972
# Epoch 45/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0038 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 0.9998
# Epoch 46/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 47/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0650 - accuracy: 0.9796 - val_loss: 0.0080 - val_accuracy: 0.9987
# Epoch 48/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0038 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 49/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 50/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# 63/63 [==============================] - 1s 4ms/step
# 500/500 [==============================] - 3s 5ms/step - loss: 9.8690e-04 - accuracy: 1.0000
# Train Accuracy for text to text model: [0.0009869028581306338, 1.0]
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9998
# Test Accuracy for text to text model: [0.0016546715050935745, 0.999833345413208]
# TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# 53+25
#  78
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_13 (LSTM)              (None, 256)               276480
#
#  repeat_vector_6 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_14 (LSTM)              (None, 3, 256)            525312
#
#  time_distributed_11 (TimeD  (None, 3, 13)             3341
#  istributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 310/313 [============================>.] - ETA: 0s - loss: 1.7861 - accuracy: 0.3205WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 6s 11ms/step - loss: 1.7850 - accuracy: 0.3205
# Epoch 2/50
# 312/313 [============================>.] - ETA: 0s - loss: 1.5244 - accuracy: 0.4083WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 1.5242 - accuracy: 0.4082
# Epoch 3/50
# 312/313 [============================>.] - ETA: 0s - loss: 1.2713 - accuracy: 0.5028WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 1.2714 - accuracy: 0.5028
# Epoch 4/50
# 308/313 [============================>.] - ETA: 0s - loss: 1.1326 - accuracy: 0.5579WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 1.1322 - accuracy: 0.5580
# Epoch 5/50
# 313/313 [==============================] - ETA: 0s - loss: 1.0512 - accuracy: 0.5943WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 1.0512 - accuracy: 0.5943
# Epoch 6/50
# 312/313 [============================>.] - ETA: 0s - loss: 1.0104 - accuracy: 0.6062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 1.0102 - accuracy: 0.6063
# Epoch 7/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.9762 - accuracy: 0.6208WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.9764 - accuracy: 0.6209
# Epoch 8/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.9500 - accuracy: 0.6301WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.9498 - accuracy: 0.6303
# Epoch 9/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.9326 - accuracy: 0.6369WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.9326 - accuracy: 0.6369
# Epoch 10/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.9205 - accuracy: 0.6415WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.9206 - accuracy: 0.6414
# Epoch 11/50
# 313/313 [==============================] - ETA: 0s - loss: 0.9047 - accuracy: 0.6502WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.9047 - accuracy: 0.6502
# Epoch 12/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.8839 - accuracy: 0.6596WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8840 - accuracy: 0.6597
# Epoch 13/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.8800 - accuracy: 0.6603WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8796 - accuracy: 0.6603
# Epoch 14/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.8629 - accuracy: 0.6683WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8628 - accuracy: 0.6683
# Epoch 15/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.8600 - accuracy: 0.6738WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8599 - accuracy: 0.6740
# Epoch 16/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.8268 - accuracy: 0.6884WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8266 - accuracy: 0.6885
# Epoch 17/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.7805 - accuracy: 0.7089WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.7800 - accuracy: 0.7092
# Epoch 18/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.6984 - accuracy: 0.7400WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6983 - accuracy: 0.7398
# Epoch 19/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.5807 - accuracy: 0.7931WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5800 - accuracy: 0.7936
# Epoch 20/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.4589 - accuracy: 0.8477WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4582 - accuracy: 0.8482
# Epoch 21/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8822WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.3719 - accuracy: 0.8823
# Epoch 22/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.2868 - accuracy: 0.9171WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.2864 - accuracy: 0.9172
# Epoch 23/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.2166 - accuracy: 0.9434WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2162 - accuracy: 0.9436
# Epoch 24/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.1876 - accuracy: 0.9498WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1868 - accuracy: 0.9501
# Epoch 25/50
# 313/313 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9678WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1378 - accuracy: 0.9678
# Epoch 26/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1236 - accuracy: 0.9701
# Epoch 27/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9797WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0934 - accuracy: 0.9798
# Epoch 28/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9736WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0962 - accuracy: 0.9736
# Epoch 29/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9783WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0830 - accuracy: 0.9783
# Epoch 30/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9884WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0535 - accuracy: 0.9884
# Epoch 31/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9773WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0762 - accuracy: 0.9772
# Epoch 32/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9767WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0769 - accuracy: 0.9766
# Epoch 33/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.0402 - accuracy: 0.9895WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0402 - accuracy: 0.9895
# Epoch 34/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0229 - accuracy: 0.9961
# Epoch 35/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9724WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0838 - accuracy: 0.9724
# Epoch 36/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9859WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0508 - accuracy: 0.9859
# Epoch 37/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9988WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0125 - accuracy: 0.9987
# Epoch 38/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9725WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0819 - accuracy: 0.9725
# Epoch 39/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9938WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0251 - accuracy: 0.9939
# Epoch 40/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9980WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0113 - accuracy: 0.9980
# Epoch 41/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9813WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0558 - accuracy: 0.9813
# Epoch 42/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9980WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0122 - accuracy: 0.9980
# Epoch 43/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0552 - accuracy: 0.9818
# Epoch 44/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9890WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0376 - accuracy: 0.9890
# Epoch 45/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9997WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0059 - accuracy: 0.9997
# Epoch 46/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9815WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0571 - accuracy: 0.9816
# Epoch 47/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9883WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0394 - accuracy: 0.9882
# Epoch 48/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9931WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0246 - accuracy: 0.9932
# Epoch 49/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 50/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0024 - accuracy: 1.0000
# 313/313 [==============================] - 2s 4ms/step
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Train Accuracy for text to text model: [0.0020791473798453808, 1.0]
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0048 - accuracy: 0.9993
# Test Accuracy for text to text model: [0.004848802927881479, 0.9992666840553284]
# TRAIN, VALID, TEST Percentage 25.0 0.0 75.0
# 53+25
#  78
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 256)               276480
#
#  repeat_vector_7 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_16 (LSTM)              (None, 3, 256)            525312
#
#  time_distributed_12 (TimeD  (None, 3, 13)             3341
#  istributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.9071 - accuracy: 0.2911WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 4s 11ms/step - loss: 1.9045 - accuracy: 0.2910
# Epoch 2/75
# 155/157 [============================>.] - ETA: 0s - loss: 1.6842 - accuracy: 0.3415WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.6837 - accuracy: 0.3417
# Epoch 3/75
# 155/157 [============================>.] - ETA: 0s - loss: 1.5817 - accuracy: 0.3885WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.5821 - accuracy: 0.3881
# Epoch 4/75
# 155/157 [============================>.] - ETA: 0s - loss: 1.4454 - accuracy: 0.4344WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.4447 - accuracy: 0.4348
# Epoch 5/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.3117 - accuracy: 0.4868WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.3119 - accuracy: 0.4871
# Epoch 6/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.2368 - accuracy: 0.5123WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.2357 - accuracy: 0.5123
# Epoch 7/75
# 153/157 [============================>.] - ETA: 0s - loss: 1.1428 - accuracy: 0.5611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1432 - accuracy: 0.5610
# Epoch 8/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.1206 - accuracy: 0.5593WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1197 - accuracy: 0.5597
# Epoch 9/75
# 156/157 [============================>.] - ETA: 0s - loss: 1.0522 - accuracy: 0.5986WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.0521 - accuracy: 0.5988
# Epoch 10/75
# 153/157 [============================>.] - ETA: 0s - loss: 1.0437 - accuracy: 0.5942WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.0443 - accuracy: 0.5942
# Epoch 11/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.0325 - accuracy: 0.5989WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 1.0318 - accuracy: 0.5993
# Epoch 12/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.9896 - accuracy: 0.6204WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9896 - accuracy: 0.6204
# Epoch 13/75
# 157/157 [==============================] - ETA: 0s - loss: 0.9868 - accuracy: 0.6186WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.9868 - accuracy: 0.6186
# Epoch 14/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.9663 - accuracy: 0.6274WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9663 - accuracy: 0.6276
# Epoch 15/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.9490 - accuracy: 0.6332WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9489 - accuracy: 0.6333
# Epoch 16/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.9412 - accuracy: 0.6375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9413 - accuracy: 0.6375
# Epoch 17/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.9233 - accuracy: 0.6442WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9233 - accuracy: 0.6443
# Epoch 18/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.9295 - accuracy: 0.6420WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9287 - accuracy: 0.6426
# Epoch 19/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.9185 - accuracy: 0.6475WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.9183 - accuracy: 0.6474
# Epoch 20/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.8976 - accuracy: 0.6582WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8962 - accuracy: 0.6591
# Epoch 21/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.8995 - accuracy: 0.6524WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.8998 - accuracy: 0.6525
# Epoch 22/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.8814 - accuracy: 0.6611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8818 - accuracy: 0.6609
# Epoch 23/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.8766 - accuracy: 0.6661WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8773 - accuracy: 0.6657
# Epoch 24/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.8537 - accuracy: 0.6775WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8538 - accuracy: 0.6772
# Epoch 25/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.8547 - accuracy: 0.6749WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8547 - accuracy: 0.6746
# Epoch 26/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.8562 - accuracy: 0.6765WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8560 - accuracy: 0.6766
# Epoch 27/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.8276 - accuracy: 0.6902WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8276 - accuracy: 0.6903
# Epoch 28/75
# 157/157 [==============================] - ETA: 0s - loss: 0.8308 - accuracy: 0.6866WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.8308 - accuracy: 0.6866
# Epoch 29/75
# 157/157 [==============================] - ETA: 0s - loss: 0.7968 - accuracy: 0.7013WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.7968 - accuracy: 0.7013
# Epoch 30/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.7913 - accuracy: 0.7028WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.7910 - accuracy: 0.7031
# Epoch 31/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.7613 - accuracy: 0.7152WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.7608 - accuracy: 0.7155
# Epoch 32/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.7475 - accuracy: 0.7159WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.7473 - accuracy: 0.7158
# Epoch 33/75
# 157/157 [==============================] - ETA: 0s - loss: 0.7171 - accuracy: 0.7350WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.7171 - accuracy: 0.7350
# Epoch 34/75
# 157/157 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.7414WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.6942 - accuracy: 0.7414
# Epoch 35/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.6446 - accuracy: 0.7658WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.6430 - accuracy: 0.7663
# Epoch 36/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.5813 - accuracy: 0.7880WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.5813 - accuracy: 0.7877
# Epoch 37/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.5286 - accuracy: 0.8121WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.5283 - accuracy: 0.8121
# Epoch 38/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.4892 - accuracy: 0.8265WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.4891 - accuracy: 0.8264
# Epoch 39/75
# 157/157 [==============================] - ETA: 0s - loss: 0.4325 - accuracy: 0.8498WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.4325 - accuracy: 0.8498
# Epoch 40/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8659WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.3962 - accuracy: 0.8659
# Epoch 41/75
# 157/157 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8981WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.3333 - accuracy: 0.8981
# Epoch 42/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.3067 - accuracy: 0.9050WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.3061 - accuracy: 0.9049
# Epoch 43/75
# 157/157 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.9152WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.2770 - accuracy: 0.9152
# Epoch 44/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9443WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.2228 - accuracy: 0.9444
# Epoch 45/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.2240 - accuracy: 0.9372WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.2239 - accuracy: 0.9371
# Epoch 46/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.2059 - accuracy: 0.9438WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.2061 - accuracy: 0.9437
# Epoch 47/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1798 - accuracy: 0.9529WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1796 - accuracy: 0.9529
# Epoch 48/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.1554 - accuracy: 0.9638WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1553 - accuracy: 0.9637
# Epoch 49/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9663WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1446 - accuracy: 0.9663
# Epoch 50/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9681WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1341 - accuracy: 0.9681
# Epoch 51/75
# 157/157 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9760WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1112 - accuracy: 0.9760
# Epoch 52/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9808WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0969 - accuracy: 0.9809
# Epoch 53/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9753WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1052 - accuracy: 0.9752
# Epoch 54/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.1034 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1033 - accuracy: 0.9722
# Epoch 55/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9661WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1224 - accuracy: 0.9664
# Epoch 56/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9932WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0528 - accuracy: 0.9933
# Epoch 57/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9929WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0510 - accuracy: 0.9927
# Epoch 58/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9901WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0540 - accuracy: 0.9900
# Epoch 59/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9682WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1050 - accuracy: 0.9681
# Epoch 60/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1807 - accuracy: 0.9395WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.1796 - accuracy: 0.9399
# Epoch 61/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9917WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0485 - accuracy: 0.9917
# Epoch 62/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0302 - accuracy: 0.9961
# Epoch 63/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9941WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0329 - accuracy: 0.9941
# Epoch 64/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9907WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0423 - accuracy: 0.9907
# Epoch 65/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0845 - accuracy: 0.9741
# Epoch 66/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9919WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0369 - accuracy: 0.9919
# Epoch 67/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0309 - accuracy: 0.9936
# Epoch 68/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9964WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0232 - accuracy: 0.9965
# Epoch 69/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9987WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0147 - accuracy: 0.9987
# Epoch 70/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0238 - accuracy: 0.9951
# Epoch 71/75
# 157/157 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9283WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 10ms/step - loss: 0.2028 - accuracy: 0.9283
# Epoch 72/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0441 - accuracy: 0.9909
# Epoch 73/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9949WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0268 - accuracy: 0.9949
# Epoch 74/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0116 - accuracy: 0.9991
# Epoch 75/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9993WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0093 - accuracy: 0.9993
# 469/469 [==============================] - 2s 4ms/step
# 157/157 [==============================] - 2s 6ms/step - loss: 0.0067 - accuracy: 0.9999
# Train Accuracy for text to text model: [0.006714425515383482, 0.9999333620071411]
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0389 - accuracy: 0.9883
# Test Accuracy for text to text model: [0.038914043456315994, 0.9883111119270325]
# TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# 53+25
#  78
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None,
100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4639 - accuracy: 0.8386WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4648 - accuracy: 0.8377
# Epoch 67/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.8583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4343 - accuracy: 0.8580
# Epoch 68/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4297 - accuracy: 0.8531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4317 - accuracy: 0.8525
# Epoch 69/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.4051 - accuracy: 0.8634WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.4047 - accuracy: 0.8647
# Epoch 70/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8829WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3713 - accuracy: 0.8815
# Epoch 71/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.3511 - accuracy: 0.8873WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3515 - accuracy: 0.8872
# Epoch 72/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.3419 - accuracy: 0.8919WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3429 - accuracy: 0.8920
# Epoch 73/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.3295 - accuracy: 0.8966WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3305 - accuracy: 0.8950
# Epoch 74/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.3217 - accuracy: 0.8984WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3217 - accuracy: 0.8983
# Epoch 75/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.3023 - accuracy: 0.9066WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3021 - accuracy: 0.9063
# Epoch 76/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2653 - accuracy: 0.9254WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2653 - accuracy: 0.9252
# Epoch 77/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2435 - accuracy: 0.9361WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2443 - accuracy: 0.9355
# Epoch 78/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.9409WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2355 - accuracy: 0.9405
# Epoch 79/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.9365WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2421 - accuracy: 0.9360
# Epoch 80/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2072 - accuracy: 0.9520WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2068 - accuracy: 0.9523
# Epoch 81/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2301 - accuracy: 0.9373WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2314 - accuracy: 0.9365
# Epoch 82/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.2284 - accuracy: 0.9357WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2267 - accuracy: 0.9363
# Epoch 83/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1703 - accuracy: 0.9681WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1700 - accuracy: 0.9677
# Epoch 84/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1609 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1617 - accuracy: 0.9698
# Epoch 85/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1638 - accuracy: 0.9664WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1641 - accuracy: 0.9665
# Epoch 86/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9508WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1898 - accuracy: 0.9508
# Epoch 87/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9628WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1698 - accuracy: 0.9633
# Epoch 88/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1508 - accuracy: 0.9689WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1504 - accuracy: 0.9692
# Epoch 89/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1418 - accuracy: 0.9696WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1411 - accuracy: 0.9697
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9765WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1294 - accuracy: 0.9765
# Epoch 91/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1232 - accuracy: 0.9773WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1227 - accuracy: 0.9777
# Epoch 92/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9855WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1042 - accuracy: 0.9850
# Epoch 93/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0996 - accuracy: 0.9827
# Epoch 94/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9874WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0992 - accuracy: 0.9868
# Epoch 95/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1147 - accuracy: 0.9768
# Epoch 96/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9676WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1260 - accuracy: 0.9678
# Epoch 97/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1064 - accuracy: 0.9783
# Epoch 98/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1248 - accuracy: 0.9659WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1258 - accuracy: 0.9653
# Epoch 99/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1490 - accuracy: 0.9595WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1490 - accuracy: 0.9593
# Epoch 100/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0879 - accuracy: 0.9853WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0872 - accuracy: 0.9858
# 563/563 [==============================] - 3s 4ms/step
# 63/63 [==============================] - 1s 4ms/step - loss: 0.0687 - accuracy: 0.9917
# Train Accuracy for text to text model: [0.06874980032444, 0.9916666746139526]
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4698 - accuracy: 0.8386
# Test Accuracy for text to text model: [0.46983692049980164, 0.8386296033859253]
