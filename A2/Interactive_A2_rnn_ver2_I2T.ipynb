# %% [markdown]
# Connected to .venv (Python 3.10.7)

# %% [markdown]
#  <div style="text-align: right">   </div>
#  Introduction to Deep Learning (2024)
#
#  **Assignment 2 - Sequence processing using RNNs**
#  <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#  # Introduction
#
#  The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs).
#  Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
#  <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
#  In this assignment you will be working with three different kinds of models, based on input/output data modalities:
#
#  1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
#
#  2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
#
#  3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#  ### Description
#
#  Let us suppose that we want to develop a neural network that learns how to add or subtract
#
#  two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
#
#  ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
#
#  sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
#
#  we want to build a model that generalizes well - if the network can extract the underlying principles behind
#
#  the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
#
#  valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
#
#  2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
#
#  The example above describes a text-to-text sequence mapping scenario. However, we can also use different
#
#  modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
#
#  dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
#  *To work on this notebook you should create a copy of it.*

# %% [markdown]
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, LSTM, Flatten, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector, Conv2D, ConvLSTM2D # type: ignore
# Out:
# 2024-12-12 03:19:04.094753: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-12 03:19:04.109735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-12 03:19:04.117863: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-12 03:19:04.120275: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-12 03:19:04.126472: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-12 03:19:06.977110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from scipy.ndimage import rotate


# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))
show_generated(generate_images(sign='-'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=False)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=False)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #4832
#
# X_text: "24+16" = y_text: " 40"
# ==================================================
# Query #2306
#
# X_text: "11+53" = y_text: " 64"
# ==================================================
# Query #8579
#
# X_text: "42-89" = y_text: "-47"
# ==================================================
# Query #5732
#
# X_text: "28+66" = y_text: " 94"
# ==================================================
# Query #395
#
# X_text: " 1-97" = y_text: "-96"
# ==================================================
# Query #824
#
# X_text: " 4+12" = y_text: " 16"
# ==================================================
# Query #9863
#
# X_text: "49-31" = y_text: " 18"
# ==================================================
# Query #253
#
# X_text: " 1-26" = y_text: "-25"
# ==================================================
# Query #4918
#
# X_text: "24+59" = y_text: " 83"
# ==================================================
# Query #9756
#
# X_text: "48+78" = y_text: "126"

# %% [markdown]
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
#  ## II. Image to text RNN Model
#
#  Hint: There are two ways of building the encoder for such a model - again by using the regular LSTM cells (with flattened images as input vectors) or
#  recurrect convolutional layers [ConvLSTM2D](https://keras.io/api/layers/recurrent_layers/conv_lstm2d/).
#
#  The goal here is to use **X_img** as inputs and **y_text** as outputs.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_img, y_text_onehot, test_size=0.20, random_state=42) 
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
print(decode_labels(y_test[0]))

plt.imshow(np.hstack(X_test[0]), cmap='gray')  # Display the frame in grayscale
plt.title(f"X")
plt.axis("off")
plt.show()
# Out:
# -70

# %%
## Your code
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D, ConvLSTM2D,MaxPooling2D, BatchNormalization, Dropout,LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2


def build_img2text_model():
    # We start by initializing a sequential model
    img2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).

    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).

    img2text.add(
        ConvLSTM2D(filters=16,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        input_shape=(5, 28, 28, 1), 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())
    img2text.add(Dropout(0.2))
    
    img2text.add(
        ConvLSTM2D(filters=32,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())

    #img2text.add(Flatten())
    img2text.add(TimeDistributed(GlobalAveragePooling2D()))
    img2text.add(Dense(256, activation='relu'))
    img2text.add(Dropout(0.2))
    
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    img2text.add(GlobalAveragePooling1D())
    img2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    img2text.add(LSTM(128, return_sequences=True))
    img2text.add(LSTM(64, return_sequences=True))
    img2text.add(LayerNormalization())

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax',kernel_regularizer=l2(0.01))))

    # Next we compile the model using categorical crossentropy as our loss function.
    optimizer = Adam(learning_rate=0.001) 
    img2text.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    img2text.summary()

    return img2text

def build_img2text_model2():
    img2text = tf.keras.Sequential()
    img2text.add(TimeDistributed(Conv2D(512, (3, 3), activation='relu'), input_shape=(5, 28, 28, 1)))
    img2text.add(TimeDistributed(MaxPooling2D((2, 2))))
    img2text.add(TimeDistributed(Dropout(0.2)))
    img2text.add(TimeDistributed(Flatten()))
    img2text.add(TimeDistributed(Dense(256, activation='relu')))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(LSTM(256))
    
    img2text.add(RepeatVector(max_answer_length))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    img2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    img2text.summary()

    return img2text

model = build_img2text_model2()
# Out:
# /vol/home/s3777103/Documents/workspace/Sem1/IDL-11/.venv/lib/python3.10/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733969988.107082 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.132862 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.132950 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.134781 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.134899 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.135037 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.172252 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.172327 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1733969988.172378 1143507 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-12 03:19:48.172426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6230 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 5, 26, 26, 512) │         5,120 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 5, 86528)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 5, 256)         │    22,151,424 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 5, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 3, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 3, 13)          │         3,341 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,735,821 (90.54 MB)
#  Trainable params: 23,735,821 (90.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow.keras as keras
# Fit the model

checkpoint_cb = keras.callbacks.ModelCheckpoint(
        f"image_to_text_best.keras", save_best_only=True
    )
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # metric to monitor
    patience=8,          # number of epochs to wait for improvement
    restore_best_weights=True  # restore the best weights after stopping
)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1)

# %%
## Your code
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D, ConvLSTM2D,MaxPooling2D, BatchNormalization, Dropout,LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2


def build_img2text_model():
    # We start by initializing a sequential model
    img2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).

    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).

    img2text.add(
        ConvLSTM2D(filters=16,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        input_shape=(5, 28, 28, 1), 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())
    img2text.add(Dropout(0.2))
    
    img2text.add(
        ConvLSTM2D(filters=32,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())

    #img2text.add(Flatten())
    img2text.add(TimeDistributed(GlobalAveragePooling2D()))
    img2text.add(Dense(256, activation='relu'))
    img2text.add(Dropout(0.2))
    
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    img2text.add(GlobalAveragePooling1D())
    img2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    img2text.add(LSTM(128, return_sequences=True))
    img2text.add(LSTM(64, return_sequences=True))
    img2text.add(LayerNormalization())

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax',kernel_regularizer=l2(0.01))))

    # Next we compile the model using categorical crossentropy as our loss function.
    optimizer = Adam(learning_rate=0.001) 
    img2text.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    img2text.summary()

    return img2text

def build_img2text_model2():
    img2text = tf.keras.Sequential()
    img2text.add(TimeDistributed(Conv2D(512, (3, 3), activation='relu'), input_shape=(5, 28, 28, 1)))
    img2text.add(TimeDistributed(MaxPooling2D((2, 2))))
    img2text.add(TimeDistributed(Dropout(0.2)))
    img2text.add(TimeDistributed(Flatten()))
    img2text.add(TimeDistributed(Dense(200, activation='relu')))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(LSTM(256))
    
    img2text.add(RepeatVector(max_answer_length))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    img2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    img2text.summary()

    return img2text

model = build_img2text_model2()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_6              │ (None, 5, 26, 26, 512) │         5,120 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 5, 86528)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 5, 200)         │    17,305,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 5, 256)         │       467,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 3, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 3, 13)          │         3,341 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,832,853 (71.84 MB)
#  Trainable params: 18,832,853 (71.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow.keras as keras
# Fit the model

checkpoint_cb = keras.callbacks.ModelCheckpoint(
        f"image_to_text_best.keras", save_best_only=True
    )
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # metric to monitor
    patience=8,          # number of epochs to wait for improvement
    restore_best_weights=True  # restore the best weights after stopping
)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=8,
    epochs=100,
    callbacks = [checkpoint_cb, early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# 2024-12-12 03:22:18.989472: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/time_distributed_8_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-12-12 03:22:19.157915: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1733970139.194842 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.209531 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.210298 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.215910 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.216679 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.217785 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.218555 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.219324 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.230132 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.238801 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.239633 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.240455 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.241263 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.242657 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.243615 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.244390 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970139.245979 1143641 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#    7/2000 ━━━━━━━━━━━━━━━━━━━━ 55s 28ms/step - accuracy: 0.1066 - loss: 2.5473
# W0000 00:00:1733970140.266458 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.267481 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.268187 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.268900 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.269618 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.270759 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.271705 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.272602 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.273519 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.274459 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.275338 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.276241 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.277144 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.278129 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.279702 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.281273 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.282411 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970140.283491 1143649 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 60s 29ms/step - accuracy: 0.2708 - loss: 1.8838 - val_accuracy: 0.3297 - val_loss: 1.7137 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 55s 28ms/step - accuracy: 0.3746 - loss: 1.5972 - val_accuracy: 0.2302 - val_loss: 3.0393 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.4919 - loss: 1.3043 - val_accuracy: 0.2113 - val_loss: 3.3799 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 55s 28ms/step - accuracy: 0.5644 - loss: 1.1566 - val_accuracy: 0.2237 - val_loss: 3.4872 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.6106 - loss: 1.0548 - val_accuracy: 0.2583 - val_loss: 3.4222 - learning_rate: 0.0010
# Epoch 6/100
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6861 - loss: 0.8796
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.6861 - loss: 0.8796 - val_accuracy: 0.2797 - val_loss: 2.9868 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.8290 - loss: 0.5519 - val_accuracy: 0.2810 - val_loss: 3.7052 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9144 - loss: 0.3554 - val_accuracy: 0.2810 - val_loss: 4.1157 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9459 - loss: 0.2568 - val_accuracy: 0.2575 - val_loss: 4.7676 - learning_rate: 5.0000e-04

# %%
import pandas as pd
data_history = pd.DataFrame(history.history)
data_history.to_csv('image_to_text_history.csv')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('epochs')
plt.ylabel('score')
plt.legend(loc="best")

plt.grid(True)
plt.tight_layout()
plt.show()

print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.3451 - loss: 1.6727
# Train Accuracy for text to text model: [1.6709380149841309, 0.344145804643631]
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3451 - loss: 1.6697
# Test Accuracy for text to text model: [1.6711069345474243, 0.3429999351501465]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
predictions = model.predict(X_test)
y_pred = [decode_labels(y) for y in predictions]
y_actual = [decode_labels(y) for y in y_test]

accuracy = accuracy_score(y_actual, y_pred)
print("Accuracy for image to text model:", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Accuracy for image to text model: 0.0155

# %%
import tensorflow.keras as keras
# Fit the model

checkpoint_cb = keras.callbacks.ModelCheckpoint(
        f"image_to_text_best.keras", save_best_only=True
    )
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # metric to monitor
    patience=15,          # number of epochs to wait for improvement
    restore_best_weights=True  # restore the best weights after stopping
)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100,
    callbacks = [checkpoint_cb, early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# W0000 00:00:1733970807.658176 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970807.875523 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970807.876618 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970807.877691 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970807.878772 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970807.879847 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.114741 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.116356 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.118222 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.120226 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.121870 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.124049 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.125662 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.156537 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.203119 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.250345 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.267315 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.269351 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.271785 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.274361 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.277071 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.306115 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.365797 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.368584 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.400602 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.402739 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.404777 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.408346 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.411715 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.478553 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970808.480928 1143644 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 12:15 3s/step - accuracy: 0.3229 - loss: 1.6784
# W0000 00:00:1733970809.289471 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.351430 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.353016 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.354554 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.356384 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.358200 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.360028 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.361892 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.363757 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.365617 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.367555 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.369383 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.371293 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.373150 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.374998 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.376796 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.378499 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.380386 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.382536 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.385246 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970809.389272 1143647 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3562 - loss: 1.6319
# W0000 00:00:1733970838.344855 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.345973 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.347003 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.348112 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.349278 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.350479 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.351719 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.353015 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.354672 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.355870 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.357387 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.359197 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.361838 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.364291 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.367199 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.369736 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733970838.373453 1143624 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 129ms/step - accuracy: 0.3562 - loss: 1.6318 - val_accuracy: 0.3872 - val_loss: 1.5621 - learning_rate: 5.0000e-04
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.3973 - loss: 1.5483 - val_accuracy: 0.4115 - val_loss: 1.4913 - learning_rate: 5.0000e-04
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.4273 - loss: 1.4580 - val_accuracy: 0.4608 - val_loss: 1.3948 - learning_rate: 5.0000e-04
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.4699 - loss: 1.3787 - val_accuracy: 0.4820 - val_loss: 1.3286 - learning_rate: 5.0000e-04
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5025 - loss: 1.3074 - val_accuracy: 0.5085 - val_loss: 1.2924 - learning_rate: 5.0000e-04
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5209 - loss: 1.2614 - val_accuracy: 0.5200 - val_loss: 1.2442 - learning_rate: 5.0000e-04
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5451 - loss: 1.2111 - val_accuracy: 0.5450 - val_loss: 1.2054 - learning_rate: 5.0000e-04
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5678 - loss: 1.1692 - val_accuracy: 0.5528 - val_loss: 1.1776 - learning_rate: 5.0000e-04
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5824 - loss: 1.1327 - val_accuracy: 0.5612 - val_loss: 1.1475 - learning_rate: 5.0000e-04
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.5958 - loss: 1.1026 - val_accuracy: 0.5793 - val_loss: 1.1277 - learning_rate: 5.0000e-04
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.6108 - loss: 1.0614 - val_accuracy: 0.5738 - val_loss: 1.1169 - learning_rate: 5.0000e-04
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.6251 - loss: 1.0279 - val_accuracy: 0.6073 - val_loss: 1.0671 - learning_rate: 5.0000e-04
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.6424 - loss: 0.9918 - val_accuracy: 0.6215 - val_loss: 1.0333 - learning_rate: 5.0000e-04
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.6616 - loss: 0.9423 - val_accuracy: 0.6393 - val_loss: 0.9900 - learning_rate: 5.0000e-04
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.6940 - loss: 0.8675 - val_accuracy: 0.6780 - val_loss: 0.8931 - learning_rate: 5.0000e-04
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.7255 - loss: 0.7772 - val_accuracy: 0.7208 - val_loss: 0.7970 - learning_rate: 5.0000e-04
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.7762 - loss: 0.6656 - val_accuracy: 0.7768 - val_loss: 0.6711 - learning_rate: 5.0000e-04
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.8283 - loss: 0.5437 - val_accuracy: 0.8147 - val_loss: 0.5993 - learning_rate: 5.0000e-04
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.8729 - loss: 0.4478 - val_accuracy: 0.8512 - val_loss: 0.5255 - learning_rate: 5.0000e-04
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9039 - loss: 0.3760 - val_accuracy: 0.8763 - val_loss: 0.4461 - learning_rate: 5.0000e-04
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9262 - loss: 0.3105 - val_accuracy: 0.8992 - val_loss: 0.4098 - learning_rate: 5.0000e-04
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9414 - loss: 0.2593 - val_accuracy: 0.9023 - val_loss: 0.3878 - learning_rate: 5.0000e-04
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9462 - loss: 0.2336 - val_accuracy: 0.9018 - val_loss: 0.3780 - learning_rate: 5.0000e-04
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9583 - loss: 0.1934 - val_accuracy: 0.9063 - val_loss: 0.3601 - learning_rate: 5.0000e-04
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 127ms/step - accuracy: 0.9635 - loss: 0.1714 - val_accuracy: 0.9162 - val_loss: 0.3184 - learning_rate: 5.0000e-04
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9661 - loss: 0.1561 - val_accuracy: 0.9235 - val_loss: 0.3152 - learning_rate: 5.0000e-04
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9720 - loss: 0.1330 - val_accuracy: 0.9188 - val_loss: 0.3286 - learning_rate: 5.0000e-04
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9739 - loss: 0.1214 - val_accuracy: 0.9265 - val_loss: 0.2956 - learning_rate: 5.0000e-04
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9779 - loss: 0.1088 - val_accuracy: 0.9305 - val_loss: 0.2909 - learning_rate: 5.0000e-04
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9775 - loss: 0.1033 - val_accuracy: 0.9297 - val_loss: 0.2985 - learning_rate: 5.0000e-04
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9772 - loss: 0.0995 - val_accuracy: 0.9293 - val_loss: 0.2948 - learning_rate: 5.0000e-04
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9807 - loss: 0.0921 - val_accuracy: 0.9318 - val_loss: 0.2873 - learning_rate: 5.0000e-04
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9802 - loss: 0.0849 - val_accuracy: 0.9305 - val_loss: 0.2893 - learning_rate: 5.0000e-04
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9814 - loss: 0.0830 - val_accuracy: 0.9372 - val_loss: 0.2734 - learning_rate: 5.0000e-04
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 118ms/step - accuracy: 0.9842 - loss: 0.0741 - val_accuracy: 0.9368 - val_loss: 0.2824 - learning_rate: 5.0000e-04
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9848 - loss: 0.0648 - val_accuracy: 0.9342 - val_loss: 0.2810 - learning_rate: 5.0000e-04
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9826 - loss: 0.0747 - val_accuracy: 0.9392 - val_loss: 0.2671 - learning_rate: 5.0000e-04
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9844 - loss: 0.0656 - val_accuracy: 0.9412 - val_loss: 0.2588 - learning_rate: 5.0000e-04
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9863 - loss: 0.0613 - val_accuracy: 0.9405 - val_loss: 0.2571 - learning_rate: 5.0000e-04
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9873 - loss: 0.0540 - val_accuracy: 0.9502 - val_loss: 0.2303 - learning_rate: 5.0000e-04
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9891 - loss: 0.0493 - val_accuracy: 0.9438 - val_loss: 0.2495 - learning_rate: 5.0000e-04
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9885 - loss: 0.0477 - val_accuracy: 0.9512 - val_loss: 0.2381 - learning_rate: 5.0000e-04
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9873 - loss: 0.0530 - val_accuracy: 0.9402 - val_loss: 0.2679 - learning_rate: 5.0000e-04
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9835 - loss: 0.0630 - val_accuracy: 0.9460 - val_loss: 0.2581 - learning_rate: 5.0000e-04
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9887 - loss: 0.0512 - val_accuracy: 0.9535 - val_loss: 0.2293 - learning_rate: 5.0000e-04
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9883 - loss: 0.0503 - val_accuracy: 0.9505 - val_loss: 0.2431 - learning_rate: 5.0000e-04
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9881 - loss: 0.0487 - val_accuracy: 0.9437 - val_loss: 0.2536 - learning_rate: 5.0000e-04
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9871 - loss: 0.0512 - val_accuracy: 0.9467 - val_loss: 0.2575 - learning_rate: 5.0000e-04
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9901 - loss: 0.0433 - val_accuracy: 0.9505 - val_loss: 0.2388 - learning_rate: 5.0000e-04
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9881 - loss: 0.0480 - val_accuracy: 0.9538 - val_loss: 0.2333 - learning_rate: 5.0000e-04
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9900 - loss: 0.0400 - val_accuracy: 0.9555 - val_loss: 0.2281 - learning_rate: 5.0000e-04
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9921 - loss: 0.0328 - val_accuracy: 0.9457 - val_loss: 0.2607 - learning_rate: 5.0000e-04
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9877 - loss: 0.0481 - val_accuracy: 0.9550 - val_loss: 0.2195 - learning_rate: 5.0000e-04
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9880 - loss: 0.0443 - val_accuracy: 0.9535 - val_loss: 0.2317 - learning_rate: 5.0000e-04
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 117ms/step - accuracy: 0.9902 - loss: 0.0388 - val_accuracy: 0.9477 - val_loss: 0.2593 - learning_rate: 5.0000e-04
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9899 - loss: 0.0384 - val_accuracy: 0.9550 - val_loss: 0.2325 - learning_rate: 5.0000e-04
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9910 - loss: 0.0319 - val_accuracy: 0.9555 - val_loss: 0.2295 - learning_rate: 5.0000e-04
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9937 - loss: 0.0251 - val_accuracy: 0.9497 - val_loss: 0.2612 - learning_rate: 5.0000e-04
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9893 - loss: 0.0399 - val_accuracy: 0.9603 - val_loss: 0.2239 - learning_rate: 5.0000e-04
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9934 - loss: 0.0249 - val_accuracy: 0.9540 - val_loss: 0.2402 - learning_rate: 5.0000e-04
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9925 - loss: 0.0285 - val_accuracy: 0.9533 - val_loss: 0.2467 - learning_rate: 5.0000e-04
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9901 - loss: 0.0362 - val_accuracy: 0.9540 - val_loss: 0.2481 - learning_rate: 5.0000e-04
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9910 - loss: 0.0343
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9910 - loss: 0.0344 - val_accuracy: 0.9543 - val_loss: 0.2256 - learning_rate: 5.0000e-04
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9930 - loss: 0.0274 - val_accuracy: 0.9637 - val_loss: 0.2114 - learning_rate: 2.5000e-04
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9970 - loss: 0.0145 - val_accuracy: 0.9652 - val_loss: 0.2012 - learning_rate: 2.5000e-04
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9980 - loss: 0.0104 - val_accuracy: 0.9670 - val_loss: 0.2037 - learning_rate: 2.5000e-04
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.9975 - loss: 0.0102 - val_accuracy: 0.9675 - val_loss: 0.2009 - learning_rate: 2.5000e-04
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9979 - loss: 0.0101 - val_accuracy: 0.9652 - val_loss: 0.2049 - learning_rate: 2.5000e-04
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9985 - loss: 0.0075 - val_accuracy: 0.9637 - val_loss: 0.2099 - learning_rate: 2.5000e-04
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9974 - loss: 0.0105 - val_accuracy: 0.9645 - val_loss: 0.2060 - learning_rate: 2.5000e-04
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9976 - loss: 0.0097 - val_accuracy: 0.9643 - val_loss: 0.2098 - learning_rate: 2.5000e-04
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9978 - loss: 0.0091 - val_accuracy: 0.9630 - val_loss: 0.2202 - learning_rate: 2.5000e-04
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9662 - val_loss: 0.2054 - learning_rate: 2.5000e-04
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9981 - loss: 0.0071 - val_accuracy: 0.9665 - val_loss: 0.2037 - learning_rate: 2.5000e-04
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9979 - loss: 0.0076 - val_accuracy: 0.9633 - val_loss: 0.2219 - learning_rate: 2.5000e-04
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.9518 - val_loss: 0.2631 - learning_rate: 2.5000e-04
# Epoch 77/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9954 - loss: 0.0158
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9954 - loss: 0.0158 - val_accuracy: 0.9578 - val_loss: 0.2396 - learning_rate: 2.5000e-04
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9968 - loss: 0.0116 - val_accuracy: 0.9665 - val_loss: 0.2096 - learning_rate: 1.2500e-04
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9984 - loss: 0.0065 - val_accuracy: 0.9677 - val_loss: 0.2036 - learning_rate: 1.2500e-04
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9637 - val_loss: 0.2167 - learning_rate: 1.2500e-04
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.9660 - val_loss: 0.2179 - learning_rate: 1.2500e-04
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9673 - val_loss: 0.2126 - learning_rate: 1.2500e-04

# %%
import pandas as pd
data_history = pd.DataFrame(history.history)
data_history.to_csv('image_to_text_history.csv')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('epochs')
plt.ylabel('score')
plt.legend(loc="best")

plt.grid(True)
plt.tight_layout()
plt.show()

print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.9983 - loss: 0.0079
# Train Accuracy for text to text model: [0.008325244300067425, 0.9981045126914978]
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9708 - loss: 0.1877
# Test Accuracy for text to text model: [0.19848766922950745, 0.9693332314491272]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
predictions = model.predict(X_test)
y_pred = [decode_labels(y) for y in predictions]
y_actual = [decode_labels(y) for y in y_test]

accuracy = accuracy_score(y_actual, y_pred)
print("Accuracy for image to text model:", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Accuracy for image to text model: 0.0245

# %%
y_pred
# Out:
# ['-60',
#  ' 11',
#  '-10',
#  ' 85',
#  ' 43',
#  ' 13',
#  '-17',
#  '-32',
#  ' 30',
#  ' 31',
#  '-79',
#  ' 31',
#  '-39',
#  '-44',
#  '-52',
#  '-79',
#  '141',
#  ' 73',
#  ' 27',
#  '-43',
#  '-42',
#  ' 21',
#  '-17',
#  ' -7',
#  '  3',
#  ' 11',
#  '-82',
#  ' 47',
#  ' 92',
#  '-78',
#  ' 38',
#  '-61',
#  '129',
#  ' 57',
#  '-56',
#  ' -2',
#  ' 71',
#  '158',
#  ' 39',
#  '-37',
#  '-20',
#  '-51',
#  '150',
#  '-62',
#  '-43',
#  '-18',
#  '-71',
#  '  1',
#  ' 32',
#  '183',
#  ' 13',
#  ' -2',
#  ' 65',
#  '159',
#  ' -2',
#  ' 11',
#  '-72',
#  '  3',
#  '1 2',
#  '181',
#  ' 13',
#  ' 68',
#  ' 99',
#  '-77',
#  '-17',
#  ' 79',
#  '-48',
#  ' 71',
#  '-17',
#  '-57',
#  ' 28',
#  '  2',
#  '-28',
#  ' 27',
#  '-70',
#  ' 85',
#  '118',
#  '-38',
#  '  2',
#  '-42',
#  '-72',
#  ' -2',
#  '-99',
#  ' 51',
#  ' 20',
#  ' 46',
#  '100',
#  ' 69',
#  '169',
#  ' 20',
#  ' 72',
#  ' 61',
#  ' 11',
#  '-48',
#  ' 48',
#  ' 42',
#  ' 68',
#  '  0',
#  '131',
#  '-73',
#  ' 31',
#  '198',
#  ' 75',
#  '-32',
#  '-21',
#  ' 99',
#  '-89',
#  ' 28',
#  '119',
#  '-91',
#  ' 28',
#  '188',
#  '-69',
#  '159',
#  ' -7',
#  '-28',
#  '-28',
#  '-26',
#  ' 48',
#  ' 48',
#  '-12',
#  ' 31',
#  '128',
#  '-18',
#  '-57',
#  '-19',
#  '161',
#  '-73',
#  ' -2',
#  ' 43',
#  ' 32',
#  '169',
#  '-47',
#  ' 70',
#  '-58',
#  '129',
#  ' 12',
#  ' 98',
#  ' 28',
#  '129',
#  ' 61',
#  '109',
#  ' 63',
#  ' 20',
#  ' 10',
#  ' 47',
#  '149',
#  ' 13',
#  '  2',
#  '-77',
#  ' 22',
#  ' 63',
#  ' 47',
#  ' 24',
#  ' 43',
#  '  4',
#  ' 69',
#  '-17',
#  '-22',
#  ' 51',
#  '-68',
#  ' -8',
#  ' 91',
#  ' 11',
#  ' 11',
#  ' 42',
#  '-52',
#  '152',
#  ' -7',
#  ' 30',
#  '-48',
#  '-72',
#  '130',
#  '-10',
#  ' 38',
#  ' -8',
#  ' 17',
#  '129',
#  ' -2',
#  '-70',
#  ' 30',
#  '-71',
#  ' 32',
#  ' 99',
#  '-68',
#  '-56',
#  '-49',
#  '-62',
#  '-29',
#  '189',
#  ' 32',
#  '-71',
#  ' 85',
#  ' 39',
#  ' 10',
#  ' 77',
#  '-28',
#  ' 10',
#  ' 13',
#  '-18',
#  '-78',
#  '  0',
#  '109',
#  '-44',
#  ' 93',
#  ' 59',
#  ' 18',
#  '-32',
#  '-70',
#  '  1',
#  '-67',
#  '-49',
#  '-11',
#  ' 44',
#  ' 11',
#  ' 20',
#  ' 77',
#  '-23',
#  ' 51',
#  '-17',
#  ' 43',
#  ' 11',
#  '-17',
#  ' 78',
#  ' 59',
#  '-78',
#  ' -8',
#  '180',
#  '-72',
#  ' 33',
#  ' 37',
#  ' 71',
#  ' 52',
#  '110',
#  ' 77',
#  '-12',
#  ' 40',
#  '-69',
#  '111',
#  ' 43',
#  ' 32',
#  '-28',
#  '119',
#  '-63',
#  '-89',
#  '121',
#  ' 87',
#  ' 60',
#  ' 96',
#  '-58',
#  ' 52',
#  ' 50',
#  '-52',
#  ' 90',
#  ' -9',
#  ' 65',
#  ' 61',
#  '-27',
#  '160',
#  '-77',
#  ' 45',
#  ' 44',
#  '-98',
#  '  2',
#  ' 37',
#  '168',
#  ' -8',
#  '159',
#  ' 47',
#  '-77',
#  ' 19',
#  ' 13',
#  '-27',
#  ' 32',
#  ' 17',
#  '  7',
#  ' 51',
#  ' 42',
#  '-88',
#  ' 32',
#  ' 29',
#  '130',
#  '-27',
#  '  1',
#  ' -3',
#  ' 43',
#  '-82',
#  ' 77',
#  '-38',
#  '-51',
#  ' 68',
#  ' 42',
#  '-89',
#  '-98',
#  '-73',
#  ' 11',
#  ' 79',
#  '  8',
#  '114',
#  '180',
#  '-79',
#  ' 20',
#  '-47',
#  '-17',
#  ' 23',
#  '-78',
#  '  1',
#  ' 87',
#  '-19',
#  ' 58',
#  '  7',
#  '-79',
#  ' 22',
#  ' 29',
#  ' 85',
#  '-99',
#  ' 72',
#  '111',
#  '-41',
#  '-40',
#  ' 31',
#  ' 71',
#  ' -3',
#  ' -3',
#  ' 10',
#  ' 33',
#  '-50',
#  ' 43',
#  ' -2',
#  '-53',
#  ' 22',
#  ' 33',
#  ' 59',
#  ' 42',
#  ' 48',
#  '-17',
#  ' -8',
#  ' 12',
#  ' 82',
#  '-28',
#  '  3',
#  '-98',
#  '-58',
#  '-52',
#  '-61',
#  ' 12',
#  '-59',
#  ' 53',
#  ' 32',
#  '142',
#  ' 50',
#  '  2',
#  '-76',
#  '-52',
#  ' 28',
#  ' 43',
#  '120',
#  ' 61',
#  '109',
#  ' 19',
#  ' 10',
#  '-23',
#  '-19',
#  ' -8',
#  ' 67',
#  ' 72',
#  ' -7',
#  ' 23',
#  '-92',
#  '-40',
#  ' 88',
#  '-17',
#  ' 59',
#  '138',
#  '-87',
#  '-51',
#  '-57',
#  ' 98',
#  '-17',
#  ' 73',
#  '159',
#  ' 20',
#  '-27',
#  ' 53',
#  '-12',
#  '141',
#  ' 67',
#  ' 23',
#  '-70',
#  '150',
#  '-38',
#  ' 71',
#  '-12',
#  '  2',
#  ' 33',
#  ' 58',
#  ' 51',
#  ' 22',
#  ' 32',
#  ' 91',
#  ' 37',
#  ' 49',
#  ' -2',
#  ' 59',
#  '168',
#  '-38',
#  ' 71',
#  ' -8',
#  '211',
#  '-31',
#  '138',
#  ' 13',
#  ' 50',
#  ' 55',
#  '-52',
#  ' 82',
#  '-69',
#  ' 70',
#  '125',
#  '117',
#  '-27',
#  '-57',
#  ' 22',
#  '-38',
#  ' 42',
#  ' -7',
#  '179',
#  '  2',
#  '-60',
#  '-28',
#  '-73',
#  '1-1',
#  '-85',
#  '-48',
#  ' 17',
#  '-70',
#  '  2',
#  ' 46',
#  '-17',
#  '-47',
#  '-49',
#  '-51',
#  ' 48',
#  ' 32',
#  '  2',
#  ' 55',
#  ' 77',
#  '-20',
#  ' 44',
#  '119',
#  ' 12',
#  ' 22',
#  ' -2',
#  '-80',
#  ' 14',
#  ' 33',
#  ' 68',
#  '139',
#  '-18',
#  ' -1',
#  ' 62',
#  '189',
#  ' 23',
#  ' 43',
#  '-57',
#  ' 17',
#  '139',
#  '138',
#  ' 41',
#  ' 42',
#  ' 12',
#  ' 17',
#  '  2',
#  ' 41',
#  ' -8',
#  '-79',
#  '-37',
#  '-82',
#  ' 65',
#  ' 23',
#  '-73',
#  ' 70',
#  ' 73',
#  '-80',
#  ' 43',
#  '-11',
#  ' 59',
#  ' -7',
#  '-72',
#  ' 42',
#  ' 43',
#  '  7',
#  ' 21',
#  ' -2',
#  ' 42',
#  '-52',
#  ' 52',
#  '-20',
#  ' 51',
#  '  9',
#  ' -7',
#  '162',
#  '-40',
#  '-33',
#  ' 48',
#  '-23',
#  ' 99',
#  ' 95',
#  '-30',
#  ' 19',
#  ' 48',
#  ' 31',
#  ' -8',
#  '-23',
#  ' 13',
#  '-33',
#  '169',
#  '-20',
#  ' 87',
#  '-77',
#  '  3',
#  '-71',
#  ' -2',
#  ' 60',
#  ' 32',
#  '-96',
#  '-28',
#  ' 28',
#  ' 41',
#  '-60',
#  ' 57',
#  ' 80',
#  ' 17',
#  ' 71',
#  '-58',
#  '177',
#  ' 79',
#  '-20',
#  '-87',
#  '-77',
#  '-28',
#  ' 51',
#  ' 33',
#  '101',
#  '151',
#  '-18',
#  '181',
#  ' 38',
#  ' 10',
#  ' 95',
#  '-97',
#  '-31',
#  '-32',
#  '138',
#  ' 23',
#  ' -8',
#  ' 22',
#  ' 88',
#  '-63',
#  '119',
#  ' 52',
#  '-68',
#  '-38',
#  ' 84',
#  '-38',
#  '158',
#  ' 68',
#  ' 32',
#  '-58',
#  ' 33',
#  ' 45',
#  '-98',
#  ' 68',
#  ' 13',
#  '-42',
#  '-80',
#  '-71',
#  '-32',
#  '177',
#  '139',
#  '-47',
#  '-51',
#  ' 21',
#  '-41',
#  ' 10',
#  ' -8',
#  '120',
#  '-27',
#  '-18',
#  '-67',
#  ' 32',
#  ' 78',
#  '-28',
#  ' 42',
#  ' 69',
#  ' 22',
#  '  2',
#  ' 10',
#  ' 78',
#  ' 71',
#  ' 95',
#  '-47',
#  '149',
#  '- 1',
#  '-48',
#  ' 90',
#  '-16',
#  '-99',
#  ' 17',
#  ' 96',
#  '-48',
#  '  9',
#  ' 62',
#  ' 11',
#  '-90',
#  ' 99',
#  ' 59',
#  ' -8',
#  ' 43',
#  ' -8',
#  ' 53',
#  '-78',
#  ' 63',
#  '-41',
#  '-28',
#  ' -3',
#  '105',
#  '-20',
#  '  2',
#  '-18',
#  '-78',
#  ' 13',
#  '-19',
#  '-99',
#  '-77',
#  ' 24',
#  '-72',
#  '-30',
#  '150',
#  '120',
#  ' 88',
#  ' 78',
#  '199',
#  ' 28',
#  ' 35',
#  '-62',
#  ' 18',
#  ' 69',
#  ' 29',
#  ' 17',
#  ' 33',
#  ' 45',
#  ' 43',
#  '-77',
#  ' 60',
#  ' 41',
#  '-58',
#  '-32',
#  '-48',
#  ' 98',
#  ' 60',
#  '-97',
#  '-17',
#  ' -7',
#  '-97',
#  ' 12',
#  '-20',
#  ' 11',
#  ' 53',
#  ' 68',
#  ' 14',
#  ' 23',
#  ' 22',
#  ' 48',
#  ' 38',
#  ' 43',
#  ' 39',
#  ' -2',
#  '-78',
#  ' 62',
#  ' 22',
#  ' 58',
#  '-17',
#  ' 13',
#  ' 79',
#  ' 23',
#  '-89',
#  '121',
#  ' 43',
#  ' 33',
#  '172',
#  '-49',
#  ' 27',
#  '117',
#  ' 22',
#  '100',
#  ' 98',
#  ' 41',
#  ' -8',
#  '120',
#  ' 45',
#  ' 36',
#  '110',
#  '-20',
#  ' 41',
#  ' 11',
#  ' 17',
#  '169',
#  '-58',
#  '-11',
#  '-12',
#  '-74',
#  ' 90',
#  '149',
#  '-47',
#  '-79',
#  '-32',
#  ' 82',
#  ' 11',
#  ' 31',
#  '-38',
#  '-21',
#  '-48',
#  ' 43',
#  ' 23',
#  '-58',
#  ' 68',
#  '-18',
#  ' 93',
#  ' 98',
#  ' 33',
#  '109',
#  '-82',
#  ' 31',
#  '199',
#  '  7',
#  ' 13',
#  ' 89',
#  ' 58',
#  '-63',
#  '-68',
#  '-12',
#  ' 12',
#  ' 99',
#  ' 28',
#  ' 36',
#  ' 42',
#  ' 14',
#  '  7',
#  ' 62',
#  '180',
#  ' 99',
#  ' 28',
#  ' 45',
#  '  2',
#  ' 83',
#  ' 41',
#  '-62',
#  '160',
#  ' 12',
#  '-48',
#  ' 58',
#  '159',
#  ' 48',
#  '-18',
#  ' 70',
#  '199',
#  '120',
#  '-17',
#  '-42',
#  '129',
#  ' 44',
#  '  2',
#  ' 90',
#  '-19',
#  ' 12',
#  ' 17',
#  ' 13',
#  '130',
#  ' 80',
#  ' 23',
#  '-88',
#  ' 40',
#  '-48',
#  '  2',
#  '-88',
#  '129',
#  ' 28',
#  ' 42',
#  '-20',
#  ' 11',
#  '-36',
#  ' 22',
#  '-72',
#  '  1',
#  '  0',
#  ' 64',
#  ' 38',
#  ' 14',
#  ' 41',
#  '-72',
#  '-89',
#  '-48',
#  ' 77',
#  '-57',
#  ' 13',
#  '-48',
#  '119',
#  ' 42',
#  '139',
#  ' 23',
#  ' 33',
#  ' 21',
#  ' 42',
#  '  2',
#  ' -3',
#  '-37',
#  '-12',
#  ' 10',
#  '-56',
#  '-38',
#  '-47',
#  ' 68',
#  ' 65',
#  ' 87',
#  '-30',
#  '-17',
#  '-17',
#  '  8',
#  ' 90',
#  ' 67',
#  '-47',
#  ' 42',
#  ' 43',
#  ' 32',
#  ' -7',
#  ' -8',
#  ' -7',
#  ' 10',
#  '  2',
#  '199',
#  ' -7',
#  '134',
#  '189',
#  '-72',
#  ' 73',
#  ' 12',
#  '-11',
#  '-57',
#  ' 57',
#  ' 32',
#  ' 72',
#  '-79',
#  ' 34',
#  ' 71',
#  ' 14',
#  ' 61',
#  ' 45',
#  '-30',
#  '  9',
#  '-58',
#  '188',
#  '-12',
#  '123',
#  '159',
#  ' 28',
#  ' 22',
#  ' -9',
#  '189',
#  ' 13',
#  '138',
#  ' 49',
#  '  3',
#  ' 37',
#  ' 11',
#  '-29',
#  ' 12',
#  '-27',
#  '-71',
#  '-90',
#  ' 32',
#  ' -2',
#  '-97',
#  ' 82',
#  ' 95',
#  '-28',
#  ' 59',
#  '169',
#  '-21',
#  ' 32',
#  '131',
#  '-38',
#  '130',
#  ' -7',
#  ' 21',
#  '-17',
#  '-82',
#  '-70',
#  '  8',
#  ' 13',
#  ' 87',
#  '-48',
#  '-71',
#  '100',
#  ' 13',
#  '-37',
#  ' -7',
#  ' 81',
#  '-78',
#  ' 70',
#  ' 77',
#  ' 18',
#  '-67',
#  '-99',
#  '168',
#  ' 80',
#  ' 11',
#  '-61',
#  ' 33',
#  '-53',
#  '-38',
#  ' -7',
#  '  2',
#  '-48',
#  '168',
#  '-17',
#  ' 76',
#  ' 80',
#  ' 71',
#  '-27',
#  ' 51',
#  '  3',
#  ' 69',
#  ' 80',
#  '119',
#  ' 28',
#  '-38',
#  '-28',
#  '-39',
#  ' 48',
#  ' 41',
#  '-31',
#  ' 69',
#  '-12',
#  '161',
#  '  2',
#  ' 32',
#  '149',
#  '-62',
#  ' 95',
#  ' 28',
#  ' 52',
#  ' 32',
#  ' 28',
#  '159',
#  ' -7',
#  '161',
#  '-62',
#  '110',
#  '-34',
#  ' 23',
#  '-33',
#  ' 51',
#  '-48',
#  ' 33',
#  '-21',
#  ' 25',
#  '199',
#  ' 28',
#  '  2',
#  '-80',
#  ' 11',
#  '-22',
#  '  4',
#  '-48',
#  '-39',
#  ' 88',
#  '-32',
#  '-61',
#  ' 43',
#  ' 21',
#  ' 17',
#  '1 3',
#  '-12',
#  ' 21',
#  '161',
#  '101',
#  ' 77',
#  '100',
#  ' -8',
#  '161',
#  '149',
#  ' 58',
#  '189',
#  ' 33',
#  ' 72',
#  '-57',
#  ' 12',
#  ' 85',
#  ' 37',
#  ...]

# %%
y_actual
# Out:
# ['-70',
#  ' 11',
#  '111',
#  ' 63',
#  '164',
#  ' 17',
#  '-35',
#  '-24',
#  ' 43',
#  ' 39',
#  ' 61',
#  ' 78',
#  '  0',
#  '123',
#  '-53',
#  '115',
#  ' 71',
#  ' 78',
#  ' -3',
#  '-23',
#  '-63',
#  ' 39',
#  ' 11',
#  '193',
#  ' 48',
#  '  3',
#  ' 51',
#  ' -7',
#  '140',
#  '111',
#  ' 56',
#  '-71',
#  '135',
#  ' 33',
#  ' 37',
#  '-27',
#  ' 78',
#  '136',
#  '155',
#  '149',
#  '-20',
#  '-13',
#  '158',
#  '-54',
#  '150',
#  '-54',
#  '-36',
#  '-38',
#  ' 80',
#  '145',
#  ' 30',
#  '-12',
#  ' 40',
#  '140',
#  ' 38',
#  '107',
#  '-33',
#  ' 21',
#  '163',
#  '146',
#  ' 16',
#  ' -2',
#  ' 57',
#  '-92',
#  ' 91',
#  ' 92',
#  '  3',
#  ' 50',
#  ' 82',
#  '-34',
#  '-10',
#  ' -8',
#  '116',
#  ' -1',
#  '-59',
#  ' 85',
#  '146',
#  ' -7',
#  '-11',
#  ' 40',
#  ' 75',
#  ' -6',
#  '107',
#  '104',
#  '-59',
#  '130',
#  '155',
#  ' 52',
#  '134',
#  ' 11',
#  ' 85',
#  ' 12',
#  ' 10',
#  '-20',
#  ' 66',
#  '129',
#  '119',
#  '-26',
#  '120',
#  '-77',
#  ' 78',
#  '173',
#  ' 94',
#  '-28',
#  '132',
#  ' 77',
#  '104',
#  ' -3',
#  '100',
#  '109',
#  '119',
#  '117',
#  ' 73',
#  '169',
#  ' -1',
#  ' 94',
#  ' 71',
#  '-31',
#  ' 36',
#  ' 44',
#  '-10',
#  ' 12',
#  '108',
#  ' 32',
#  ' 62',
#  ' 87',
#  '158',
#  ' 69',
#  ' 78',
#  ' 14',
#  ' 22',
#  '160',
#  '-84',
#  ' 66',
#  '-75',
#  ' 98',
#  ' 19',
#  ' 90',
#  ' 27',
#  '129',
#  ' 38',
#  '103',
#  ' 74',
#  ' 16',
#  '-19',
#  ' 66',
#  ' 91',
#  ' 35',
#  '118',
#  '-54',
#  '-12',
#  '114',
#  ' 27',
#  ' 19',
#  '122',
#  ' 60',
#  ' 19',
#  '-29',
#  '-24',
#  ' 51',
#  '-38',
#  '  1',
#  '166',
#  ' -2',
#  '-30',
#  ' 92',
#  ' 87',
#  '173',
#  ' 15',
#  ' -7',
#  '-44',
#  '-70',
#  '151',
#  ' 97',
#  ' -1',
#  ' -1',
#  '132',
#  '121',
#  ' -7',
#  '-40',
#  ' 70',
#  '-90',
#  ' 56',
#  ' 91',
#  '-49',
#  '151',
#  '-69',
#  '103',
#  ' 42',
#  '152',
#  ' 96',
#  '-79',
#  ' 58',
#  ' -5',
#  '-10',
#  ' 56',
#  '-46',
#  ' 12',
#  '  0',
#  ' 32',
#  ' 78',
#  '-13',
#  ' 68',
#  '-24',
#  '109',
#  ' 57',
#  '-12',
#  '160',
#  '-60',
#  '-51',
#  ' 68',
#  ' 80',
#  '154',
#  '101',
#  ' 10',
#  ' 95',
#  ' 83',
#  '-50',
#  '  8',
#  ' 27',
#  ' 54',
#  ' 81',
#  ' -2',
#  '164',
#  '104',
#  ' 27',
#  ' 19',
#  '139',
#  '113',
#  '116',
#  ' 43',
#  ' 45',
#  ' 69',
#  '109',
#  ' 44',
#  '-23',
#  ' 30',
#  '-59',
#  '189',
#  '120',
#  ' 98',
#  '-33',
#  '115',
#  '-27',
#  '110',
#  '124',
#  ' 75',
#  ' 48',
#  '132',
#  '121',
#  '162',
#  '102',
#  '-48',
#  '138',
#  '-14',
#  '120',
#  ' 28',
#  '-32',
#  ' 90',
#  '-92',
#  ' 80',
#  '111',
#  '159',
#  '  8',
#  '  5',
#  '110',
#  '  2',
#  '135',
#  ' 29',
#  '-47',
#  '121',
#  ' -1',
#  '-24',
#  ' 73',
#  '  1',
#  '-14',
#  ' 55',
#  ' -3',
#  ' 92',
#  ' 85',
#  ' 22',
#  '160',
#  ' 50',
#  '-35',
#  ' 32',
#  ' 93',
#  '-80',
#  ' 57',
#  '119',
#  '-45',
#  ' 87',
#  ' 52',
#  '-48',
#  '124',
#  '-55',
#  ' 24',
#  ' 69',
#  ' 18',
#  '107',
#  '169',
#  '-60',
#  ' 32',
#  '-25',
#  '115',
#  ' 46',
#  '-69',
#  ' 10',
#  ' 91',
#  '-14',
#  '109',
#  ' 34',
#  ' 83',
#  ' 68',
#  ' 50',
#  ' 47',
#  ' 98',
#  ' 84',
#  '160',
#  '-22',
#  '-46',
#  ' 95',
#  ' 64',
#  ' 25',
#  '-34',
#  ' 20',
#  ' 83',
#  '-41',
#  ' 67',
#  ' 11',
#  ' 17',
#  ' 40',
#  ' 52',
#  ' 47',
#  ' 41',
#  ' 77',
#  '-26',
#  ' 20',
#  ' 37',
#  '103',
#  '-24',
#  ' 70',
#  '104',
#  '-12',
#  '-24',
#  '-65',
#  ' 58',
#  ' 77',
#  ' -9',
#  ' 71',
#  '112',
#  ' 51',
#  '  1',
#  '109',
#  '-33',
#  ' 65',
#  ' 14',
#  '168',
#  '110',
#  '115',
#  ' 39',
#  '-10',
#  '-22',
#  ' -9',
#  ' 24',
#  ' 98',
#  ' 73',
#  ' 60',
#  ' 26',
#  ' 69',
#  '113',
#  '108',
#  '-41',
#  ' 85',
#  ' 99',
#  ' 93',
#  '-28',
#  '-34',
#  '117',
#  ' 97',
#  ' 92',
#  '101',
#  '-39',
#  ' 20',
#  ' 74',
#  '119',
#  '173',
#  ' 37',
#  ' 20',
#  '-92',
#  '182',
#  ' 18',
#  ' 84',
#  ' -2',
#  ' -4',
#  ' 31',
#  '  9',
#  '  5',
#  '  1',
#  ' 92',
#  '113',
#  ' 15',
#  '  8',
#  '-14',
#  ' 65',
#  '171',
#  '-16',
#  ' 68',
#  ' 22',
#  '141',
#  '139',
#  ' 97',
#  '158',
#  ' 50',
#  ' 52',
#  '-62',
#  '100',
#  '-82',
#  ' 98',
#  '142',
#  '113',
#  '144',
#  '-21',
#  ' 31',
#  '-36',
#  '110',
#  ' 16',
#  '123',
#  ' 42',
#  '-51',
#  '-25',
#  '-28',
#  '169',
#  '-75',
#  '-27',
#  '119',
#  '-68',
#  ' 15',
#  ' 43',
#  '  2',
#  '146',
#  '-50',
#  '-47',
#  ' 28',
#  ' 40',
#  '  7',
#  ' 76',
#  ' 70',
#  ' 46',
#  '164',
#  '157',
#  ' 21',
#  ' 26',
#  '177',
#  ' 77',
#  '-33',
#  ' 63',
#  ' 37',
#  '111',
#  ' 16',
#  ' 42',
#  ' 61',
#  '127',
#  ' 61',
#  ' 77',
#  '145',
#  '-33',
#  '123',
#  '169',
#  ' 76',
#  ' 98',
#  ' 27',
#  '  7',
#  ' -6',
#  ' 75',
#  '  2',
#  ' 52',
#  '-31',
#  '-60',
#  '118',
#  '  3',
#  '-46',
#  ' 93',
#  ' 86',
#  ' 85',
#  ' 74',
#  '-12',
#  ' 88',
#  '  4',
#  '-35',
#  ' 89',
#  ' 53',
#  ' 15',
#  '  2',
#  ' 32',
#  ' 84',
#  '128',
#  ' 70',
#  ' 10',
#  '-27',
#  '-41',
#  ' -2',
#  '113',
#  '-32',
#  '-18',
#  ' 68',
#  ' 85',
#  '107',
#  '100',
#  '-48',
#  ' 64',
#  ' 43',
#  '152',
#  ' -7',
#  '  4',
#  ' 18',
#  '-29',
#  '182',
#  '-47',
#  ' 51',
#  '-91',
#  '  8',
#  '-69',
#  '-17',
#  ' 20',
#  '-32',
#  ' 84',
#  '-33',
#  '105',
#  ' 45',
#  '-40',
#  ' 15',
#  ' 19',
#  ' 75',
#  ' 55',
#  '-68',
#  '125',
#  ' 52',
#  '-27',
#  '-73',
#  '-64',
#  '-12',
#  ' 33',
#  ' 37',
#  '112',
#  '120',
#  '  2',
#  '169',
#  '-27',
#  ' 61',
#  ' 57',
#  ' 95',
#  '-35',
#  ' 93',
#  '179',
#  '  1',
#  ' 65',
#  ' 17',
#  ' 91',
#  '-34',
#  '127',
#  '130',
#  '-37',
#  ' 46',
#  '105',
#  '134',
#  '113',
#  ' 90',
#  ' 43',
#  '130',
#  ' 56',
#  ' 47',
#  ' 74',
#  ' 48',
#  ' 22',
#  ' 94',
#  ' 80',
#  '-85',
#  '146',
#  '134',
#  '145',
#  '  2',
#  '-24',
#  ' 75',
#  ' 42',
#  '  6',
#  ' 36',
#  ' 89',
#  '-12',
#  ' -7',
#  '140',
#  ' 16',
#  '111',
#  '-65',
#  ' 23',
#  ' 84',
#  ' 67',
#  ' 26',
#  ' 20',
#  ' 36',
#  ' 98',
#  '112',
#  '-53',
#  '134',
#  ' 78',
#  '-31',
#  ' 95',
#  '156',
#  ' 84',
#  ' 18',
#  ' 99',
#  '155',
#  ' 24',
#  ' 34',
#  ' 12',
#  ' 55',
#  ' 90',
#  '124',
#  '-29',
#  '157',
#  ' 96',
#  ' 42',
#  ' 44',
#  ' 31',
#  ' -9',
#  '-37',
#  '  9',
#  '104',
#  '-30',
#  ' 23',
#  ' -7',
#  '-78',
#  ' 80',
#  ' 21',
#  '106',
#  '-71',
#  '-11',
#  ' 60',
#  '-40',
#  '149',
#  '124',
#  '111',
#  ' 43',
#  '179',
#  ' 17',
#  ' 25',
#  ' 69',
#  '-23',
#  '134',
#  '142',
#  ' 40',
#  ' 61',
#  '107',
#  ' 51',
#  ' 26',
#  '108',
#  ' 55',
#  '-14',
#  ' 37',
#  '-18',
#  ' 86',
#  ' 60',
#  '122',
#  ' 72',
#  ' 17',
#  '101',
#  '  9',
#  '-41',
#  ' 73',
#  ' 73',
#  ' 11',
#  '-14',
#  ' 30',
#  ' 40',
#  '107',
#  ' 19',
#  '103',
#  '109',
#  ' 14',
#  '113',
#  ' 41',
#  ' 52',
#  ' 16',
#  '-24',
#  '-18',
#  '142',
#  ' -9',
#  ' 95',
#  '139',
#  '-15',
#  ' 85',
#  '163',
#  '-11',
#  ' 50',
#  ' 71',
#  ' 18',
#  '126',
#  '105',
#  ' 49',
#  '-15',
#  '113',
#  '183',
#  ' 25',
#  '132',
#  '-23',
#  '175',
#  ' 33',
#  ' -2',
#  '150',
#  '-75',
#  '  9',
#  '-22',
#  '-45',
#  ' 83',
#  '135',
#  '-14',
#  '-79',
#  '123',
#  ' 68',
#  '127',
#  '  9',
#  '  5',
#  ' 86',
#  '119',
#  '  5',
#  ' 81',
#  '-38',
#  ' 57',
#  '-57',
#  '115',
#  '111',
#  ' 41',
#  '122',
#  '103',
#  ' 46',
#  '175',
#  ' 33',
#  '122',
#  ' 87',
#  ' 58',
#  ' 69',
#  '-79',
#  ' -6',
#  '121',
#  ' 96',
#  ' 29',
#  '108',
#  '105',
#  ' 61',
#  ' -4',
#  ' 36',
#  '108',
#  '140',
#  ' 92',
#  ' 57',
#  ' 20',
#  '184',
#  ' 46',
#  ' 81',
#  '124',
#  '  6',
#  '-27',
#  '141',
#  '180',
#  ' 16',
#  '-20',
#  ' 43',
#  '166',
#  '140',
#  '-49',
#  ' 43',
#  '124',
#  ' 79',
#  ' 77',
#  '100',
#  ' 65',
#  '111',
#  ' 63',
#  ' 48',
#  '135',
#  ' 67',
#  ' 38',
#  ' 94',
#  '-44',
#  '153',
#  ' -5',
#  ' 89',
#  '108',
#  ' 59',
#  ' 46',
#  '145',
#  ' 15',
#  ' 46',
#  ' 57',
#  '-22',
#  ' -2',
#  '-60',
#  ' 61',
#  ' 70',
#  '  6',
#  ' 43',
#  '-38',
#  '107',
#  '-58',
#  ' 46',
#  '123',
#  ' 48',
#  '135',
#  '101',
#  ' 38',
#  '136',
#  ' 55',
#  ' 26',
#  '  1',
#  '  1',
#  ' 36',
#  ' -7',
#  '-56',
#  '-41',
#  ' 28',
#  '165',
#  '-13',
#  '-51',
#  ' 47',
#  ' 43',
#  '102',
#  '-42',
#  '  6',
#  '  4',
#  '  4',
#  '122',
#  ' 41',
#  '-16',
#  ' 33',
#  ' 72',
#  ' 27',
#  '-24',
#  ' 10',
#  ' 85',
#  ' 20',
#  '-37',
#  '184',
#  '-22',
#  '113',
#  '173',
#  '-71',
#  ' 64',
#  '105',
#  '  3',
#  '120',
#  '  8',
#  ' 28',
#  ' 41',
#  '-84',
#  '-24',
#  ' 99',
#  '112',
#  '-15',
#  '111',
#  ' 62',
#  '  9',
#  '-49',
#  '186',
#  '-22',
#  '134',
#  ' 89',
#  ' 15',
#  ' 44',
#  '-36',
#  '178',
#  '  8',
#  '159',
#  ' 96',
#  '  0',
#  ' 46',
#  ' 59',
#  '-17',
#  ' 88',
#  ' 50',
#  '-72',
#  '114',
#  ' 29',
#  ' -1',
#  ' 90',
#  ' 65',
#  ' 44',
#  '-15',
#  '150',
#  '136',
#  '-16',
#  '-12',
#  ' 98',
#  '-36',
#  '120',
#  '  2',
#  ' 65',
#  '-12',
#  ' 87',
#  ' 81',
#  '-38',
#  ' 54',
#  ' 65',
#  '-35',
#  '-52',
#  ' 74',
#  ' 21',
#  '-37',
#  ' 41',
#  ' 84',
#  '-94',
#  ' 51',
#  ' 91',
#  ' 61',
#  '-18',
#  ' 55',
#  '114',
#  ' 75',
#  '  9',
#  ' 70',
#  ' 63',
#  '-43',
#  '-54',
#  ' -3',
#  '-42',
#  '-30',
#  '142',
#  '-17',
#  ' 92',
#  ' 65',
#  ' 89',
#  '-24',
#  ' 52',
#  ' 46',
#  ' 50',
#  ' 79',
#  '115',
#  ' 33',
#  '-36',
#  ' 91',
#  '-63',
#  ' 36',
#  '110',
#  '122',
#  ' 90',
#  ' 27',
#  '160',
#  '-19',
#  ' 63',
#  '117',
#  '-25',
#  '112',
#  ' 69',
#  '102',
#  ' 15',
#  ' 38',
#  '137',
#  '-27',
#  '170',
#  '-16',
#  '126',
#  '153',
#  ' 18',
#  '-47',
#  ' 53',
#  '  1',
#  ' 94',
#  '-11',
#  ' 59',
#  '176',
#  '  6',
#  ' 58',
#  '-80',
#  '-21',
#  '172',
#  ' 59',
#  '-51',
#  '-35',
#  ' 53',
#  ' 77',
#  ' -9',
#  ' 23',
#  '  6',
#  '-18',
#  '119',
#  '  7',
#  ' 98',
#  '114',
#  ' 67',
#  ' 16',
#  '149',
#  '  4',
#  '124',
#  '133',
#  ' 18',
#  '140',
#  '-16',
#  ' 62',
#  '-37',
#  '  6',
#  ' 60',
#  ' 93',
#  ...]

# %%
accuracy_score(y_actual[:3], y_pred[:3])
# Out:
# 0.3333333333333333

# %% [markdown]
#  <div style="text-align: right">   </div>
#  Introduction to Deep Learning (2024)
#
#  **Assignment 2 - Sequence processing using RNNs**
#  <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#  # Introduction
#
#  The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs).
#  Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
#  <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
#  In this assignment you will be working with three different kinds of models, based on input/output data modalities:
#
#  1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
#
#  2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
#
#  3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#  ### Description
#
#  Let us suppose that we want to develop a neural network that learns how to add or subtract
#
#  two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
#
#  ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
#
#  sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
#
#  we want to build a model that generalizes well - if the network can extract the underlying principles behind
#
#  the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
#
#  valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
#
#  2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
#
#  The example above describes a text-to-text sequence mapping scenario. However, we can also use different
#
#  modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
#
#  dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
#  *To work on this notebook you should create a copy of it.*

# %% [markdown]
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, LSTM, Flatten, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector, Conv2D, ConvLSTM2D # type: ignore

# %%
from scipy.ndimage import rotate


# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))
show_generated(generate_images(sign='-'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #1834
#
# X_text: "9+17 " = y_text: "26 "
# ==================================================
# Query #7875
#
# X_text: "39-37" = y_text: "2  "
# ==================================================
# Query #5670
#
# X_text: "28+35" = y_text: "63 "
# ==================================================
# Query #8093
#
# X_text: "40-46" = y_text: "-6 "
# ==================================================
# Query #4769
#
# X_text: "23-84" = y_text: "-61"
# ==================================================
# Query #1923
#
# X_text: "9-61 " = y_text: "-52"
# ==================================================
# Query #1344
#
# X_text: "6+72 " = y_text: "78 "
# ==================================================
# Query #1973
#
# X_text: "9-86 " = y_text: "-77"
# ==================================================
# Query #2498
#
# X_text: "12+49" = y_text: "61 "
# ==================================================
# Query #9396
#
# X_text: "46+98" = y_text: "144"

# %% [markdown]
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
#  ## II. Image to text RNN Model
#
#  Hint: There are two ways of building the encoder for such a model - again by using the regular LSTM cells (with flattened images as input vectors) or
#  recurrect convolutional layers [ConvLSTM2D](https://keras.io/api/layers/recurrent_layers/conv_lstm2d/).
#
#  The goal here is to use **X_img** as inputs and **y_text** as outputs.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_img, y_text_onehot, test_size=0.20, random_state=42) 
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
print(decode_labels(y_test[0]))

plt.imshow(np.hstack(X_test[0]), cmap='gray')  # Display the frame in grayscale
plt.title(f"X")
plt.axis("off")
plt.show()
# Out:
# -70

# %%
## Your code
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D, ConvLSTM2D,MaxPooling2D, BatchNormalization, Dropout,LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2


def build_img2text_model():
    # We start by initializing a sequential model
    img2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).

    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).

    img2text.add(
        ConvLSTM2D(filters=16,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        input_shape=(5, 28, 28, 1), 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())
    img2text.add(Dropout(0.2))
    
    img2text.add(
        ConvLSTM2D(filters=32,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())

    #img2text.add(Flatten())
    img2text.add(TimeDistributed(GlobalAveragePooling2D()))
    img2text.add(Dense(256, activation='relu'))
    img2text.add(Dropout(0.2))
    
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    img2text.add(GlobalAveragePooling1D())
    img2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    img2text.add(LSTM(128, return_sequences=True))
    img2text.add(LSTM(64, return_sequences=True))
    img2text.add(LayerNormalization())

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax',kernel_regularizer=l2(0.01))))

    # Next we compile the model using categorical crossentropy as our loss function.
    optimizer = Adam(learning_rate=0.001) 
    img2text.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    img2text.summary()

    return img2text

def build_img2text_model2():
    img2text = tf.keras.Sequential()
    img2text.add(TimeDistributed(Conv2D(512, (3, 3), activation='relu'), input_shape=(5, 28, 28, 1)))
    img2text.add(TimeDistributed(MaxPooling2D((2, 2))))
    img2text.add(TimeDistributed(Dropout(0.2)))
    img2text.add(TimeDistributed(Flatten()))
    img2text.add(TimeDistributed(Dense(200, activation='relu')))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(LSTM(256))
    
    img2text.add(RepeatVector(max_answer_length))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    img2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    img2text.summary()

    return img2text

model = build_img2text_model2()
# Out:
# /vol/home/s3777103/Documents/workspace/Sem1/IDL-11/.venv/lib/python3.10/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_12             │ (None, 5, 26, 26, 512) │         5,120 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_14             │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_15             │ (None, 5, 86528)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 5, 200)         │    17,305,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 5, 256)         │       467,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_2 (RepeatVector)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 3, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 3, 13)          │         3,341 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,832,853 (71.84 MB)
#  Trainable params: 18,832,853 (71.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow.keras as keras
# Fit the model

checkpoint_cb = keras.callbacks.ModelCheckpoint(
        f"image_to_text_best.keras", save_best_only=True
    )
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # metric to monitor
    patience=15,          # number of epochs to wait for improvement
    restore_best_weights=True  # restore the best weights after stopping
)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100,
    callbacks = [checkpoint_cb, early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# 2024-12-12 04:30:40.123127: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_2_1/time_distributed_14_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# W0000 00:00:1733974240.290830 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#   2/250 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.1055 - loss: 2.5537
# W0000 00:00:1733974240.361037 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.362226 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.363381 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.364501 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.365649 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.366918 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.368730 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.370739 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.372566 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.374434 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.376386 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.378255 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.380115 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.382280 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.385027 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.389076 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1733974240.392794 1143629 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.3196 - loss: 2.0917 - val_accuracy: 0.4067 - val_loss: 1.7344 - learning_rate: 0.0010
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.4151 - loss: 1.6786 - val_accuracy: 0.4617 - val_loss: 1.4851 - learning_rate: 0.0010
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.4889 - loss: 1.4210 - val_accuracy: 0.5357 - val_loss: 1.3029 - learning_rate: 0.0010
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.5567 - loss: 1.2385 - val_accuracy: 0.5782 - val_loss: 1.2110 - learning_rate: 0.0010
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.5895 - loss: 1.1406 - val_accuracy: 0.6003 - val_loss: 1.1441 - learning_rate: 0.0010
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.6197 - loss: 1.0464 - val_accuracy: 0.6142 - val_loss: 1.0848 - learning_rate: 0.0010
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.6370 - loss: 0.9966 - val_accuracy: 0.6437 - val_loss: 1.0167 - learning_rate: 0.0010
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.6802 - loss: 0.8799 - val_accuracy: 0.6840 - val_loss: 0.8961 - learning_rate: 0.0010
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.7569 - loss: 0.6757 - val_accuracy: 0.8253 - val_loss: 0.5966 - learning_rate: 0.0010
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.8714 - loss: 0.4194 - val_accuracy: 0.8915 - val_loss: 0.4303 - learning_rate: 0.0010
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9278 - loss: 0.2822 - val_accuracy: 0.9233 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9543 - loss: 0.1888 - val_accuracy: 0.9200 - val_loss: 0.3304 - learning_rate: 0.0010
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9557 - loss: 0.1868 - val_accuracy: 0.9477 - val_loss: 0.2471 - learning_rate: 0.0010
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9747 - loss: 0.1222 - val_accuracy: 0.9423 - val_loss: 0.2551 - learning_rate: 0.0010
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9780 - loss: 0.1063 - val_accuracy: 0.9438 - val_loss: 0.2669 - learning_rate: 0.0010
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9821 - loss: 0.0858 - val_accuracy: 0.9562 - val_loss: 0.2209 - learning_rate: 0.0010
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9841 - loss: 0.0799 - val_accuracy: 0.9515 - val_loss: 0.2426 - learning_rate: 0.0010
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9819 - loss: 0.0861 - val_accuracy: 0.9595 - val_loss: 0.2082 - learning_rate: 0.0010
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9848 - loss: 0.0698 - val_accuracy: 0.9598 - val_loss: 0.2127 - learning_rate: 0.0010
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9837 - loss: 0.0732 - val_accuracy: 0.9625 - val_loss: 0.1931 - learning_rate: 0.0010
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9903 - loss: 0.0475 - val_accuracy: 0.9630 - val_loss: 0.1994 - learning_rate: 0.0010
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9866 - loss: 0.0577 - val_accuracy: 0.9558 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9834 - loss: 0.0722 - val_accuracy: 0.9612 - val_loss: 0.2114 - learning_rate: 0.0010
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9878 - loss: 0.0560 - val_accuracy: 0.9612 - val_loss: 0.1984 - learning_rate: 0.0010
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9872 - loss: 0.0613 - val_accuracy: 0.9635 - val_loss: 0.1997 - learning_rate: 0.0010
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9889 - loss: 0.0509 - val_accuracy: 0.9693 - val_loss: 0.1725 - learning_rate: 0.0010
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9825 - loss: 0.0797 - val_accuracy: 0.9580 - val_loss: 0.2039 - learning_rate: 0.0010
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9897 - loss: 0.0454 - val_accuracy: 0.9745 - val_loss: 0.1576 - learning_rate: 0.0010
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9898 - loss: 0.0444 - val_accuracy: 0.9530 - val_loss: 0.2787 - learning_rate: 0.0010
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9817 - loss: 0.0804 - val_accuracy: 0.9678 - val_loss: 0.1809 - learning_rate: 0.0010
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9892 - loss: 0.0476 - val_accuracy: 0.9748 - val_loss: 0.1560 - learning_rate: 0.0010
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9901 - loss: 0.0469 - val_accuracy: 0.9610 - val_loss: 0.1950 - learning_rate: 0.0010
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9900 - loss: 0.0451 - val_accuracy: 0.9647 - val_loss: 0.2056 - learning_rate: 0.0010
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9908 - loss: 0.0390 - val_accuracy: 0.9722 - val_loss: 0.1677 - learning_rate: 0.0010
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9909 - loss: 0.0373 - val_accuracy: 0.9702 - val_loss: 0.1660 - learning_rate: 0.0010
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9911 - loss: 0.0335 - val_accuracy: 0.9738 - val_loss: 0.1523 - learning_rate: 0.0010
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9911 - loss: 0.0361 - val_accuracy: 0.9707 - val_loss: 0.1641 - learning_rate: 0.0010
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9904 - loss: 0.0421 - val_accuracy: 0.9590 - val_loss: 0.2254 - learning_rate: 0.0010
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9931 - loss: 0.0288 - val_accuracy: 0.9717 - val_loss: 0.1743 - learning_rate: 0.0010
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9953 - loss: 0.0175 - val_accuracy: 0.9757 - val_loss: 0.1557 - learning_rate: 0.0010
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - accuracy: 0.9958 - loss: 0.0164 - val_accuracy: 0.9763 - val_loss: 0.1475 - learning_rate: 0.0010
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9936 - loss: 0.0242 - val_accuracy: 0.9507 - val_loss: 0.2660 - learning_rate: 0.0010
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9855 - loss: 0.0538 - val_accuracy: 0.9733 - val_loss: 0.1605 - learning_rate: 0.0010
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9938 - loss: 0.0279 - val_accuracy: 0.9697 - val_loss: 0.1845 - learning_rate: 0.0010
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9938 - loss: 0.0295 - val_accuracy: 0.9712 - val_loss: 0.1803 - learning_rate: 0.0010
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9953 - loss: 0.0214 - val_accuracy: 0.9722 - val_loss: 0.1731 - learning_rate: 0.0010
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9945 - loss: 0.0238 - val_accuracy: 0.9740 - val_loss: 0.1624 - learning_rate: 0.0010
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9934 - loss: 0.0260 - val_accuracy: 0.9688 - val_loss: 0.1776 - learning_rate: 0.0010
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9942 - loss: 0.0260 - val_accuracy: 0.9663 - val_loss: 0.1976 - learning_rate: 0.0010
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9929 - loss: 0.0284 - val_accuracy: 0.9712 - val_loss: 0.1816 - learning_rate: 0.0010
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9946 - loss: 0.0218
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9946 - loss: 0.0218 - val_accuracy: 0.9703 - val_loss: 0.1978 - learning_rate: 0.0010
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9971 - loss: 0.0116 - val_accuracy: 0.9747 - val_loss: 0.1741 - learning_rate: 5.0000e-04
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9985 - loss: 0.0071 - val_accuracy: 0.9747 - val_loss: 0.1672 - learning_rate: 5.0000e-04
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9988 - loss: 0.0067 - val_accuracy: 0.9770 - val_loss: 0.1540 - learning_rate: 5.0000e-04
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9987 - loss: 0.0063 - val_accuracy: 0.9783 - val_loss: 0.1536 - learning_rate: 5.0000e-04
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9782 - val_loss: 0.1605 - learning_rate: 5.0000e-04

# %%
model.save(f'submission1_image_to_text.keras')

# %%
import pandas as pd
data_history = pd.DataFrame(history.history)
data_history.to_csv('image_to_text_history.csv')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('epochs')
plt.ylabel('score')
plt.legend(loc="best")

plt.grid(True)
plt.tight_layout()
plt.show()

print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.9965 - loss: 0.0126
# Train Accuracy for text to text model: [0.014029748737812042, 0.9962506294250488]
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9794 - loss: 0.1409
# Test Accuracy for text to text model: [0.1635618358850479, 0.9763333797454834]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
predictions = model.predict(X_test)
y_pred = [decode_labels(y) for y in predictions]
y_actual = [decode_labels(y) for y in y_test]

accuracy = accuracy_score(y_actual, y_pred)
print("Accuracy for image to text model:", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Accuracy for image to text model: 0.012

# %%
## Your code
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D, ConvLSTM2D,MaxPooling2D, BatchNormalization, Dropout,LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2


def build_img2text_model():
    # We start by initializing a sequential model
    img2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).

    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).

    img2text.add(
        ConvLSTM2D(filters=16,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        input_shape=(5, 28, 28, 1), 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())
    img2text.add(Dropout(0.2))
    
    img2text.add(
        ConvLSTM2D(filters=32,
        kernel_size=(3, 3),
        padding="same",
        return_sequences=True,
        activation="relu", 
        kernel_regularizer=l2(0.01))
    )
    img2text.add(BatchNormalization())

    #img2text.add(Flatten())
    img2text.add(TimeDistributed(GlobalAveragePooling2D()))
    img2text.add(Dense(256, activation='relu'))
    img2text.add(Dropout(0.2))
    
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    img2text.add(GlobalAveragePooling1D())
    img2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    img2text.add(LSTM(128, return_sequences=True))
    img2text.add(LSTM(64, return_sequences=True))
    img2text.add(LayerNormalization())

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax',kernel_regularizer=l2(0.01))))

    # Next we compile the model using categorical crossentropy as our loss function.
    optimizer = Adam(learning_rate=0.001) 
    img2text.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    img2text.summary()

    return img2text

def build_img2text_model2():
    img2text = tf.keras.Sequential()
    img2text.add(TimeDistributed(Conv2D(512, (3, 3), activation='relu'), input_shape=(5, 28, 28, 1)))
    img2text.add(TimeDistributed(MaxPooling2D((2, 2))))
    img2text.add(TimeDistributed(Dropout(0.2)))
    img2text.add(TimeDistributed(Flatten()))
    img2text.add(TimeDistributed(Dense(200, activation='relu')))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(LSTM(256))
    
    img2text.add(RepeatVector(max_answer_length))
    img2text.add(LSTM(256, return_sequences=True))
    img2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    img2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    img2text.summary()

    return img2text

model = build_img2text_model2()
# Out:
# /vol/home/s3777103/Documents/workspace/Sem1/IDL-11/.venv/lib/python3.10/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_18             │ (None, 5, 26, 26, 512) │         5,120 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_19             │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_20             │ (None, 5, 13, 13, 512) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 5, 86528)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 5, 200)         │    17,305,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 5, 256)         │       467,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_3 (RepeatVector)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 3, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 3, 13)          │         3,341 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,832,853 (71.84 MB)
#  Trainable params: 18,832,853 (71.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow.keras as keras
# Fit the model

checkpoint_cb = keras.callbacks.ModelCheckpoint(
        f"image_to_text_best.keras", save_best_only=True
    )
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # metric to monitor
    patience=8,          # number of epochs to wait for improvement
    restore_best_weights=True  # restore the best weights after stopping
)

lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=8,
    epochs=100,
    callbacks = [checkpoint_cb, early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
#    1/2000 ━━━━━━━━━━━━━━━━━━━━ 45:36 1s/step - accuracy: 0.1667 - loss: 2.5644
# 2024-12-12 04:58:21.553293: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_3_1/time_distributed_20_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 59s 29ms/step - accuracy: 0.3709 - loss: 1.9193 - val_accuracy: 0.2425 - val_loss: 3.0279 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 58s 29ms/step - accuracy: 0.4909 - loss: 1.4178 - val_accuracy: 0.2977 - val_loss: 2.7462 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.5842 - loss: 1.1730 - val_accuracy: 0.2800 - val_loss: 3.0393 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.7033 - loss: 0.8498 - val_accuracy: 0.2650 - val_loss: 3.7575 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.8335 - loss: 0.5540 - val_accuracy: 0.2718 - val_loss: 4.9055 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.8883 - loss: 0.3987 - val_accuracy: 0.2468 - val_loss: 5.5557 - learning_rate: 0.0010
# Epoch 7/100
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9217 - loss: 0.2957
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9217 - loss: 0.2957 - val_accuracy: 0.2512 - val_loss: 5.8896 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9651 - loss: 0.1697 - val_accuracy: 0.2522 - val_loss: 5.6810 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9754 - loss: 0.1337 - val_accuracy: 0.2492 - val_loss: 5.9920 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 56s 28ms/step - accuracy: 0.9758 - loss: 0.1194 - val_accuracy: 0.2578 - val_loss: 6.0116 - learning_rate: 5.0000e-04

# %%
model.save(f'submission1_image_to_text.keras')

# %%
import pandas as pd
data_history = pd.DataFrame(history.history)
data_history.to_csv('image_to_text_history.csv')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('epochs')
plt.ylabel('score')
plt.legend(loc="best")

plt.grid(True)
plt.tight_layout()
plt.show()

print("Train Accuracy for text to text model:", model.evaluate(X_train, y_train))
print("Test Accuracy for text to text model:", model.evaluate(X_test, y_test))
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.5623 - loss: 1.2233
# Train Accuracy for text to text model: [1.2218360900878906, 0.562437891960144]
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5565 - loss: 1.2430
# Test Accuracy for text to text model: [1.243869423866272, 0.5541666150093079]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
predictions = model.predict(X_test)
y_pred = [decode_labels(y) for y in predictions]
y_actual = [decode_labels(y) for y in y_test]

accuracy = accuracy_score(y_actual, y_pred)
print("Accuracy for image to text model:", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Accuracy for image to text model: 0.007

# %%
X_train.shape
# Out:
# (16000, 5, 28, 28)

# %%
X_test.shape
# Out:
# (2000, 5, 28, 28)

# %%
X_valid.shape
# Out:
# (2000, 5, 28, 28)
