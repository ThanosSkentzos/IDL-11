# %% [markdown]
# # %% [markdown]
#
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
# %%

import matplotlib.pyplot as plt
import cv2

import numpy as np
import pandas as pd

import tensorflow.keras as keras # type: ignore
from tensorflow.keras.layers import Dense, LSTM, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector # type: ignore


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from collections import Counter
from sklearn.metrics import confusion_matrix
from matplotlib.colors import LogNorm
import seaborn as sns
# Out:
# 2024-12-13 23:15:24.694813: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-13 23:15:24.719022: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-13 23:15:24.719038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-13 23:15:24.719772: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-13 23:15:24.723820: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-13 23:15:27.540998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %%

from scipy.ndimage import rotate


np.random.seed(42)

# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())

# %%
# %%

def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=False)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=False)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
# # %% [markdown]
#
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# %%

# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(2):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #6745
#
# X_text: "33-72" = y_text: "-39"
# ==================================================
# Query #2107
#
# X_text: "10-53" = y_text: "-43"

# %% [markdown]
# # %% [markdown]
#
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# %%

# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
# # %% [markdown]
#
#  ---
#
#  ## I. Text-to-text RNN model
#
#  The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
#  1. LSTM
#
#  2. TimeDistributed
#
#  3. RepeatVector
#
#  The code cell below explains each of these new components.
#
#  <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
# %%

def build_text2text_model():
    # We start by initializing a sequential model
    text2text = keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. 
    # Repeat 3 times as that's the maximum length of the output (e.g. ' 1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True)) 

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

def build_text2text_model_additional_lstm():
    text2text = keras.Sequential()
    text2text.add(LSTM(128, input_shape=(None, len(unique_characters)), return_sequences=True))
    text2text.add(LSTM(128))
    text2text.add(RepeatVector(max_answer_length))
    text2text.add(LSTM(256, return_sequences=True)) 
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()
    return text2text

# %%
# %%

## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)

data_percentage = [
    [80.0, 10.0, 10.0, 50], 
    [50.0, 0.0, 50.0, 50], 
    [25.0, 0.0, 75.0, 75], 
    [10.0, 0.0, 90.0, 100]
]
models=[]
for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, 
                                                        random_state=42) 

    # Fit the model
    model = build_text2text_model()
    # model = build_text2text_model_additional_lstm()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), 
                                                            random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',         # metric to monitor
            patience=10,                # number of epochs to wait for improvement
            restore_best_weights=True   # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")
    plt.title(f"{each[0]}, {each[1]}, {each[2]}")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Result for TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    print("Train Accuracy for text to text model: ", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model: ", model.evaluate(X_test, y_test))
    print("Test String Accuracy: ", accuracy)

    #to clear cache
    models.append(model)
    continue
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 2024-12-13 23:15:35.782019: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.807855: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.807948: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.809218: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.809293: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.809350: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.859574: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.859666: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.859727: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 23:15:35.859774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6224 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-12-13 23:15:35.933775: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-12-13 23:15:35.933785: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2024-12-13 23:15:35.933806: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               276480
#
#  repeat_vector (RepeatVecto  (None, 3, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed (TimeDist  (None, 3, 13)             3341
#  ributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 2024-12-13 23:15:37.036491: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-12-13 23:15:37.083901: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.158788: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.158815: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.159365: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.160331: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.160357: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.160371: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.160391: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.160408: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.287983: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.288003: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.288020: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.288891: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.288918: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.289213: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.289478: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.289705: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.385184: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.416052: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.506654: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.506684: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.506712: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.506803: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.506879: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.507371: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.507776: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.510825: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.511545: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:15:37.700699: I external/local_xla/xla/service/service.cc:168] XLA service 0x799462c98070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-13 23:15:37.700714: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2024-12-13 23:15:37.703357: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#  17/500 [>.............................] - ETA: 1s - loss: 2.5193 - accuracy: 0.2181
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734128137.747597 2705700 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 500/500 [==============================] - 5s 6ms/step - loss: 1.7166 - accuracy: 0.3445 - val_loss: 1.4794 - val_accuracy: 0.4252
# Epoch 2/50
# 500/500 [==============================] - 3s 5ms/step - loss: 1.2802 - accuracy: 0.4981 - val_loss: 1.1731 - val_accuracy: 0.5293
# Epoch 3/50
# 500/500 [==============================] - 2s 5ms/step - loss: 1.0919 - accuracy: 0.5755 - val_loss: 1.0813 - val_accuracy: 0.5743
# Epoch 4/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.
50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 0.1281 - val_accuracy: 0.9562
# Epoch 36/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0346 - accuracy: 0.9894 - val_loss: 0.0101 - val_accuracy: 0.9975
# Epoch 37/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.0417 - val_accuracy: 0.9855
# Epoch 38/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.0115 - val_accuracy: 0.9975
# Epoch 39/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0492 - accuracy: 0.9854 - val_loss: 0.0098 - val_accuracy: 0.9985
# Epoch 40/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.0044 - val_accuracy: 0.9992
# Epoch 41/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0077 - val_accuracy: 0.9980
# Epoch 42/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0608 - accuracy: 0.9808 - val_loss: 0.0123 - val_accuracy: 0.9973
# Epoch 43/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.0094 - val_accuracy: 0.9978
# Epoch 44/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0033 - val_accuracy: 0.9995
# Epoch 45/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9997
# Epoch 46/50
# 500/500 [==============================] - 3s 6ms/step - loss: 9.5161e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9997
# Epoch 47/50
# 500/500 [==============================] - 2s 5ms/step - loss: 7.7630e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9997
# Epoch 48/50
# 500/500 [==============================] - 2s 4ms/step - loss: 6.5906e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9997
# Epoch 49/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1016 - accuracy: 0.9706 - val_loss: 0.0103 - val_accuracy: 0.9983
# Epoch 50/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0382 - val_accuracy: 0.9893
# 63/63 [==============================] - 0s 582us/step
# Result for TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 500/500 [==============================] - 1s 982us/step - loss: 0.0281 - accuracy: 0.9917
# Train Accuracy for text to text model:  [0.028130749240517616, 0.9916874766349792]
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 0.9903
# Test Accuracy for text to text model:  [0.030528239905834198, 0.9903333187103271]
# Test String Accuracy:  0.971
# TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 256)               276480
#
#  repeat_vector_1 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_3 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed_1 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
#   1/313 [..............................] - ETA: 5:10 - loss: 2.5654 - accuracy: 0.0729
# 2024-12-13 23:17:40.655038: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:17:40.656584: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 23:17:40.656599: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 311/313 [============================>.] - ETA: 0s - loss: 1.8014 - accuracy: 0.3106WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 5ms/step - loss: 1.8005 - accuracy: 0.3109
# Epoch 2/50
# 306/313 [============================>.] - ETA: 0s - loss: 1.5415 - accuracy: 0.3994WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 1.5380 - accuracy: 0.4014
# Epoch 3/50
# 302/313 [===========================>..] - ETA: 0s - loss: 1.2935 - accuracy: 0.4918WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 4ms/step - loss: 1.2908 - accuracy: 0.4933
# Epoch 4/50
# 305/313 [============================>.] - ETA: 0s - loss: 1.1578 - accuracy: 0.5490WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1559 - accuracy: 0.5505
# Epoch 5/50
# 312/313 [============================>.] - ETA: 0s - loss: 1.0786 - accuracy: 0.5808WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0786 - accuracy: 0.5808
# Epoch 6/50
# 310/313 [============================>.] - ETA: 0s - loss: 1.0187 - accuracy: 0.6039WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 5ms/step - loss: 1.0184 - accuracy: 0.6042
# Epoch 7/50
# 313/313 [==============================] - ETA: 0s - loss: 0.9855 - accuracy: 0.6176WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 4ms/step - loss: 0.
ARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3150 - accuracy: 0.9055
# Epoch 74/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2950 - accuracy: 0.9075WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2947 - accuracy: 0.9078
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.9235WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2707 - accuracy: 0.9235
# Epoch 76/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.2461 - accuracy: 0.9373WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2468 - accuracy: 0.9357
# Epoch 77/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.9324WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2448 - accuracy: 0.9330
# Epoch 78/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2325 - accuracy: 0.9361WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2335 - accuracy: 0.9352
# Epoch 79/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.2434 - accuracy: 0.9326WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.9320
# Epoch 80/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.9279WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2450 - accuracy: 0.9285
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9467WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2122 - accuracy: 0.9467
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9487WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2006 - accuracy: 0.9487
# Epoch 83/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.2142 - accuracy: 0.9393WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2130 - accuracy: 0.9403
# Epoch 84/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1952 - accuracy: 0.9520WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9518
# Epoch 85/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1544 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.9712
# Epoch 86/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1587 - accuracy: 0.9671WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1583 - accuracy: 0.9675
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9690WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1545 - accuracy: 0.9690
# Epoch 88/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1397 - accuracy: 0.9746WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1397 - accuracy: 0.9745
# Epoch 89/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1287 - accuracy: 0.9775WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9767
# Epoch 90/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1452 - accuracy: 0.9709WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1443 - accuracy: 0.9718
# Epoch 91/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1402 - accuracy: 0.9680WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1403 - accuracy: 0.9678
# Epoch 92/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.1537 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9572
# Epoch 93/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1637 - accuracy: 0.9578WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1639 - accuracy: 0.9575
# Epoch 94/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1540 - accuracy: 0.9590WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1551 - accuracy: 0.9580
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1240 - accuracy: 0.9732
# Epoch 96/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0940 - accuracy: 0.9889WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0943 - accuracy: 0.9892
# Epoch 97/100
# 50/63 [======================>.......] - ETA: 0s - loss: 0.1035 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1044 - accuracy: 0.9810
# Epoch 98/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0924 - accuracy: 0.9861WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9862
# Epoch 99/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.0716 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9942
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9945WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0669 - accuracy: 0.9945
# 563/563 [==============================] - 1s 1ms/step
# Result for TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.9940
# Train Accuracy for text to text model:  [0.06119843199849129, 0.9940000176429749]
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3967 - accuracy: 0.8638
# Test Accuracy for text to text model:  [0.3967232406139374, 0.8637962937355042]
# Test String Accuracy:  0.6387777777777778

# %%
#%%

# check that we get correct results -> done
preds = [list(map(decode_labels,m.predict(X_test))) for m in models]
trues = list(map(decode_labels,y_test))
scores = [accuracy_score(trues,i) for i in preds+[trues]]
scores_chars = [accuracy_score(list("".join(trues)), list("".join(i))) for i in preds+[trues]]
evals = [m.evaluate(X_test,y_test)[1] for m in models] + [1]
# Out:
# 563/563 [==============================] - 1s 1ms/step
# 563/563 [==============================] - 1s 2ms/step
# 563/563 [==============================] - 1s 2ms/step
# 563/563 [==============================] - 1s 1ms/step
# 563/563 [==============================] - 1s 1ms/step - loss: 0.0294 - accuracy: 0.9914
# 563/563 [==============================] - 0s 763us/step - loss: 0.0054 - accuracy: 0.9990
# 563/563 [==============================] - 0s 760us/step - loss: 0.0273 - accuracy: 0.9919
# 563/563 [==============================] - 0s 841us/step - loss: 0.3967 - accuracy: 0.8638

# %%
#%%

l = []
columns = [",".join([str(i) for i in l]) for l in data_percentage]
for model_preds in preds:
    # fig, ax = plt.subplots(2, 2, figsize=(25, 20))
    for i in range(3):
        pos_pred = [p[i] for p in model_preds]
        pos_true = [t[i] for t in trues]
        cm = confusion_matrix(pos_pred,pos_true)
        # print(pos,":",sns.heatmap(pos_pred,pos_true))

        # g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
        # ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
        # ax[int(i/2)][i%2].set_xlabel('Predicted')
        # ax[int(i/2)][i%2].set_ylabel('True')
        mistakes = (1-accuracy_score(pos_true,pos_pred))*len(pos_pred)
        l.append(int(mistakes+0.1))
mistakes = pd.DataFrame(np.array(l).reshape(4,-1))
mistakes.index = columns
mistakes.columns = ["100s position","10s position","1s position"]
mistakes.plot.bar(log=True,rot=8,cmap="coolwarm")
plt.savefig('mistakes.png')

# %%
#%%

# when do we get a decreased accuracy and why
# entire output numbers
columns = [",".join([str(i) for i in l]) for l in data_percentage] + ['true']
score_df = pd.DataFrame([scores,scores_chars, evals])
score_df.index=["test_string_accuracy","test_character_accuracy","test_evaluated_accuracy"]
score_df.columns = columns
df = pd.DataFrame(preds+[trues]).T
df.columns = columns
print(score_df)
# df.plot.scatter(columns[1],columns[-1])
# df.plot.scatter(columns[2],columns[-1])
# df.plot.scatter(columns[3],columns[-1])
# Out:
#                          80.0,10.0,10.0,50  50.0,0.0,50.0,50  \
# test_string_accuracy              0.974278          0.997556
# test_character_accuracy           0.991389          0.999037
# test_evaluated_accuracy           0.991389          0.999037
#
#                          25.0,0.0,75.0,75  10.0,0.0,90.0,100  true
# test_string_accuracy             0.976889           0.638778   1.0
# test_character_accuracy          0.991889           0.863796   1.0
# test_evaluated_accuracy          0.991889           0.863796   1.0

# %%
#%%

# df.plot.scatter(columns[0],columns[-1])

# %%
#%%

# symbol by symbol
wrong_positions = [np.argwhere(np.array(p)!=trues) for p in preds]
# visualize the differences perhaps scatterplot
#find out what kind of mistakes your models make on the misclassified samples.
wrong_data = [X_test[pos] for pos in wrong_positions]

# decoded_wrong_inputs = [[list(map(decode_labels,data)) for data in model_wrong_data] for model_wrong_data in wrong_data]
wrong_outputs = [np.array(p)[idx] for idx,p in zip(wrong_positions,preds)]
wrong_out_characters = ["".join([str(i) for i in w.ravel()]) for w in wrong_outputs]
correct_characters = ["".join([str(i) for i in np.array(trues)[idx].ravel()]) for idx in wrong_positions ]

pred_characters = ["".join([str(i) for i in y]) for y in preds]
true_characters = "".join([str(char) for y in trues for char in y])
mapping = {i:n for i,n in zip(unique_characters,range(len(unique_characters)))}

counts = [Counter([(true,pred) for true,pred in zip(true_characters,chars)]) for chars in pred_characters]


fig, ax = plt.subplots(2, 2, figsize=(25, 20))
for i in range(len(models)):
    # Compute confusion matrix
    cm = confusion_matrix(list(true_characters), list(pred_characters[i]))
    
    g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
    g.set_xticklabels(['ws', 'neg'] + list('0123456789'))
    g.set_yticklabels(['ws', 'neg'] + list('0123456789'))
    ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
    ax[int(i/2)][i%2].set_xlabel('Predicted')
    ax[int(i/2)][i%2].set_ylabel('True')

plt.show()

# %%
# %%

## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)

data_percentage = [
    [80.0, 10.0, 10.0, 50], 
    [50.0, 0.0, 50.0, 50], 
    [25.0, 0.0, 75.0, 75], 
    [10.0, 0.0, 90.0, 100]
]
models=[]
for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, 
                                                        random_state=42) 

    # Fit the model
    # model = build_text2text_model()
    model = build_text2text_model_additional_lstm()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), 
                                                            random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',         # metric to monitor
            patience=10,                # number of epochs to wait for improvement
            restore_best_weights=True   # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")
    plt.title(f"{each[0]}, {each[1]}, {each[2]}")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Result for TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    print("Train Accuracy for text to text model: ", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model: ", model.evaluate(X_test, y_test))
    print("Test String Accuracy: ", accuracy)

    #to clear cache
    models.append(model)
    continue
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, None, 128)         72704
#
#  lstm_9 (LSTM)               (None, 128)               131584
#
#  repeat_vector_4 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_10 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_4 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 5s 8ms/step - loss: 1.7539 - accuracy: 0.3240 - val_loss: 1.5657 - val_accuracy: 0.3917
# Epoch 2/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.4247 - accuracy: 0.4403 - val_loss: 1.2424 - val_accuracy: 0.4938
# Epoch 3/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.1236 - accuracy: 0.5575 - val_loss: 1.0373 - val_accuracy: 0.5968
# Epoch 4/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.
50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0167 - accuracy: 0.9954 - val_loss: 0.0187 - val_accuracy: 0.9957
# Epoch 36/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0487 - accuracy: 0.9853 - val_loss: 0.0344 - val_accuracy: 0.9907
# Epoch 37/50
# 500/500 [==============================] - 4s 7ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 0.0046 - val_accuracy: 0.9993
# Epoch 38/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0425 - accuracy: 0.9865 - val_loss: 0.0493 - val_accuracy: 0.9833
# Epoch 39/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0110 - val_accuracy: 0.9968
# Epoch 40/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0.0392 - accuracy: 0.9872 - val_loss: 0.0475 - val_accuracy: 0.9857
# Epoch 41/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.0026 - val_accuracy: 0.9998
# Epoch 42/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0324 - val_accuracy: 0.9892
# Epoch 43/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 0.0082 - val_accuracy: 0.9980
# Epoch 44/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.0569 - val_accuracy: 0.9813
# Epoch 45/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0.0311 - accuracy: 0.9903 - val_loss: 0.0184 - val_accuracy: 0.9943
# Epoch 46/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 47/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9998
# Epoch 48/50
# 500/500 [==============================] - 1s 3ms/step - loss: 7.3845e-04 - accuracy: 1.0000 - val_loss: 9.6725e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 500/500 [==============================] - 1s 2ms/step - loss: 5.8279e-04 - accuracy: 1.0000 - val_loss: 7.9652e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 500/500 [==============================] - 2s 3ms/step - loss: 4.6642e-04 - accuracy: 1.0000 - val_loss: 6.7592e-04 - val_accuracy: 1.0000
# 63/63 [==============================] - 0s 871us/step
# Result for TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 500/500 [==============================] - 1s 995us/step - loss: 4.1890e-04 - accuracy: 1.0000
# Train Accuracy for text to text model:  [0.0004189017054159194, 1.0]
# 63/63 [==============================] - 0s 988us/step - loss: 6.4258e-04 - accuracy: 1.0000
# Test Accuracy for text to text model:  [0.0006425816682167351, 1.0]
# Test String Accuracy:  1.0
# TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, None, 128)         72704
#
#  lstm_12 (LSTM)              (None, 128)               131584
#
#  repeat_vector_5 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_13 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_5 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 301/313 [===========================>..] - ETA: 0s - loss: 1.8323 - accuracy: 0.2987WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 4s 7ms/step - loss: 1.8275 - accuracy: 0.2996
# Epoch 2/50
# 302/313 [===========================>..] - ETA: 0s - loss: 1.5724 - accuracy: 0.3877WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5712 - accuracy: 0.3879
# Epoch 3/50
# 304/313 [============================>.] - ETA: 0s - loss: 1.3955 - accuracy: 0.4494WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3930 - accuracy: 0.4504
# Epoch 4/50
# 295/313 [===========================>..] - ETA: 0s - loss: 1.2071 - accuracy: 0.5222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2022 - accuracy: 0.5241
# Epoch 5/50
# 307/313 [============================>.] - ETA: 0s - loss: 1.0926 - accuracy: 0.5676WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0917 - accuracy: 0.5679
# Epoch 6/50
# 296/313 [===========================>..] - ETA: 0s - loss: 1.0296 - accuracy: 0.5981WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.
ARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0986 - accuracy: 0.9708
# Epoch 35/50
# 301/313 [===========================>..] - ETA: 0s - loss: 0.0802 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0795 - accuracy: 0.9767
# Epoch 36/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0610 - accuracy: 0.9828
# Epoch 37/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9816WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0621 - accuracy: 0.9813
# Epoch 38/50
# 298/313 [===========================>..] - ETA: 0s - loss: 0.0950 - accuracy: 0.9683WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0922 - accuracy: 0.9695
# Epoch 39/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9910WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0359 - accuracy: 0.9910
# Epoch 40/50
# 313/313 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9859WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0484 - accuracy: 0.9859
# Epoch 41/50
# 307/313 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9800WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0619 - accuracy: 0.9801
# Epoch 42/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9926WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0272 - accuracy: 0.9926
# Epoch 43/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.0720 - accuracy: 0.9754WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0718 - accuracy: 0.9754
# Epoch 44/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9966WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0160 - accuracy: 0.9966
# Epoch 45/50
# 306/313 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9884WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0416 - accuracy: 0.9876
# Epoch 46/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9831WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0536 - accuracy: 0.9832
# Epoch 47/50
# 307/313 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9991
# Epoch 48/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9813WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0675 - accuracy: 0.9813
# Epoch 49/50
# 307/313 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0607 - accuracy: 0.9815
# Epoch 50/50
# 307/313 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9989WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9988
# 313/313 [==============================] - 1s 810us/step
# Result for TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# 313/313 [==============================] - 1s 962us/step - loss: 0.0110 - accuracy: 0.9975
# Train Accuracy for text to text model:  [0.011036277748644352, 0.9974666833877563]
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 0.9962
# Test Accuracy for text to text model:  [0.016435012221336365, 0.9962000250816345]
# Test String Accuracy:  0.9892
# TRAIN, VALID, TEST Percentage 25.0 0.0 75.0
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, None, 128)         72704
#
#  lstm_15 (LSTM)              (None, 128)               131584
#
#  repeat_vector_6 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_16 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_6 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 155/157 [============================>.] - ETA: 0s - loss: 1.9498 - accuracy: 0.2670WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 3s 7ms/step - loss: 1.9482 - accuracy: 0.2677
# Epoch 2/75
# 153/157 [============================>.] - ETA: 0s - loss: 1.7089 - accuracy: 0.3263WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.7081 - accuracy: 0.3272
# Epoch 3/75
# 155/157 [============================>.] - ETA: 0s - loss: 1.6274 - accuracy: 0.3653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 1.6272 - accuracy: 0.3653
# Epoch 4/75
# 156/157 [============================>.] - ETA: 0s - loss: 1.5379 - accuracy: 0.3992WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 1.5378 - accuracy: 0.3991
# Epoch 5/75
# 153/157 [============================>.] - ETA: 0s - loss: 1.4681 - accuracy: 0.4213WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.4664 - accuracy: 0.4220
# Epoch 6/75
# 152/157 [============================>.] - ETA: 0s - loss: 1.3663 - accuracy: 0.4649WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.3643 - accuracy: 0.4657
# Epoch 7/75
# 156/157 [============================>.] - ETA: 0s - loss: 1.2479 - accuracy: 0.5119WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.
ARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1448 - accuracy: 0.9625
# Epoch 71/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.9581WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1475 - accuracy: 0.9581
# Epoch 72/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.1457 - accuracy: 0.9568WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1494 - accuracy: 0.9557
# Epoch 73/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9495WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1623 - accuracy: 0.9498
# Epoch 74/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1068 - accuracy: 0.9724
# Epoch 75/75
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0951 - accuracy: 0.9778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0962 - accuracy: 0.9773
# 469/469 [==============================] - 1s 2ms/step
# Result for TRAIN, VALID, TEST Percentage 25.0 0.0 75.0
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1173 - accuracy: 0.9687
# Train Accuracy for text to text model:  [0.11729611456394196, 0.9687333106994629]
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1853 - accuracy: 0.9366
# Test Accuracy for text to text model:  [0.1852509081363678, 0.9365555644035339]
# Test String Accuracy:  0.8231333333333334
# TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None, None, 128)         72704
#
#  lstm_18 (LSTM)              (None, 128)               131584
#
#  repeat_vector_7 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_19 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_7 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.2252 - accuracy: 0.2221WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 2s 6ms/step - loss: 2.1939 - accuracy: 0.2227
# Epoch 2/100
# 61/63 [============================>.] - ETA: 0s - loss: 1.8000 - accuracy: 0.2949WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7984 - accuracy: 0.2957
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 1.7204 - accuracy: 0.3240WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 1.7204 - accuracy: 0.3240
# Epoch 4/100
# 62/63 [============================>.] - ETA: 0s - loss: 1.7124 - accuracy: 0.3266WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 1.7119 - accuracy: 0.3267
# Epoch 5/100
# 58/63 [==========================>...] - ETA: 0s - loss: 1.6810 - accuracy: 0.3464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# 63/63 [==============================] - 0s 8ms/step - loss: 0.9643 - accuracy: 0.6308
# Epoch 42/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.8655 - accuracy: 0.6733WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.8659 - accuracy: 0.6728
# Epoch 43/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.8535 - accuracy: 0.6850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8555 - accuracy: 0.6838
# Epoch 44/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.8561 - accuracy: 0.6796WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8559 - accuracy: 0.6792
# Epoch 45/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.8477 - accuracy: 0.6818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.8555 - accuracy: 0.6792
# Epoch 46/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.9003 - accuracy: 0.6610WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 1s 8ms/step - loss: 0.8964 - accuracy: 0.6622
# Epoch 47/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.8448 - accuracy: 0.6792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8436 - accuracy: 0.6805
# Epoch 48/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.8654 - accuracy: 0.6735WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8669 - accuracy: 0.6725
# Epoch 49/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.8476 - accuracy: 0.6752WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8502 - accuracy: 0.6738
# Epoch 50/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.8849 - accuracy: 0.6626WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8839 - accuracy: 0.6617
# Epoch 51/100
# 61/63 [============================>.] - ETA: 0s - loss: 0
100
# 62/63 [============================>.] - ETA: 0s - loss: 0.5515 - accuracy: 0.8041WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.5522 - accuracy: 0.8040
# Epoch 87/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.5303 - accuracy: 0.8146WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.5321 - accuracy: 0.8123
# Epoch 88/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.5500 - accuracy: 0.7963WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 3ms/step - loss: 0.5515 - accuracy: 0.7950
# Epoch 89/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.5434 - accuracy: 0.8046WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5413 - accuracy: 0.8057
# Epoch 90/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4994 - accuracy: 0.8239WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5004 - accuracy: 0.8232
# Epoch 91/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.4631 - accuracy: 0.8399WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4633 - accuracy: 0.8393
# Epoch 92/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.4607 - accuracy: 0.8400WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8382
# Epoch 93/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.4456 - accuracy: 0.8460WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4457 - accuracy: 0.8477
# Epoch 94/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.4343 - accuracy: 0.8456WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.4345 - accuracy: 0.8455
# Epoch 95/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.4325 - accuracy: 0.8475WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4365 - accuracy: 0.8455
# Epoch 96/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.4259 - accuracy: 0.8482WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.8478
# Epoch 97/100
# 51/63 [=======================>......] - ETA: 0s - loss: 0.4212 - accuracy: 0.8464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4211 - accuracy: 0.8458
# Epoch 98/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.3517 - accuracy: 0.8794WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8778
# Epoch 99/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.3283 - accuracy: 0.8928WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8928
# Epoch 100/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.3234 - accuracy: 0.8940WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3248 - accuracy: 0.8933
# 563/563 [==============================] - 2s 2ms/step
# Result for TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2982 - accuracy: 0.9108
# Train Accuracy for text to text model:  [0.29816868901252747, 0.9108333587646484]
# 563/563 [==============================] - 1s 2ms/step - loss: 0.7235 - accuracy: 0.7397
# Test Accuracy for text to text model:  [0.7235088348388672, 0.7396851778030396]
# Test String Accuracy:  0.322

# %%
#%%

# check that we get correct results -> done
preds = [list(map(decode_labels,m.predict(X_test))) for m in models]
trues = list(map(decode_labels,y_test))
scores = [accuracy_score(trues,i) for i in preds+[trues]]
scores_chars = [accuracy_score(list("".join(trues)), list("".join(i))) for i in preds+[trues]]
evals = [m.evaluate(X_test,y_test)[1] for m in models] + [1]
# Out:
# 563/563 [==============================] - 1s 3ms/step
# 563/563 [==============================] - 0s 770us/step
# 563/563 [==============================] - 1s 911us/step
# 563/563 [==============================] - 1s 2ms/step
# 563/563 [==============================] - 1s 2ms/step - loss: 4.7312e-04 - accuracy: 1.0000
# 563/563 [==============================] - 1s 2ms/step - loss: 0.0140 - accuracy: 0.9967
# 563/563 [==============================] - 2s 3ms/step - loss: 0.1735 - accuracy: 0.9422
# 563/563 [==============================] - 2s 3ms/step - loss: 0.7235 - accuracy: 0.7397

# %%
#%%

l = []
columns = [",".join([str(i) for i in l]) for l in data_percentage]
for model_preds in preds:
    # fig, ax = plt.subplots(2, 2, figsize=(25, 20))
    for i in range(3):
        pos_pred = [p[i] for p in model_preds]
        pos_true = [t[i] for t in trues]
        cm = confusion_matrix(pos_pred,pos_true)
        # print(pos,":",sns.heatmap(pos_pred,pos_true))

        # g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
        # ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
        # ax[int(i/2)][i%2].set_xlabel('Predicted')
        # ax[int(i/2)][i%2].set_ylabel('True')
        mistakes = (1-accuracy_score(pos_true,pos_pred))*len(pos_pred)
        l.append(int(mistakes+0.1))
mistakes = pd.DataFrame(np.array(l).reshape(4,-1))
mistakes.index = columns
mistakes.columns = ["100s position","10s position","1s position"]
mistakes.plot.bar(log=True,rot=8,cmap="coolwarm")
plt.savefig('mistakes.png')

# %%
#%%

# when do we get a decreased accuracy and why
# entire output numbers
columns = [",".join([str(i) for i in l]) for l in data_percentage] + ['true']
score_df = pd.DataFrame([scores,scores_chars, evals])
score_df.index=["test_string_accuracy","test_character_accuracy","test_evaluated_accuracy"]
score_df.columns = columns
df = pd.DataFrame(preds+[trues]).T
df.columns = columns
print(score_df)
# df.plot.scatter(columns[1],columns[-1])
# df.plot.scatter(columns[2],columns[-1])
# df.plot.scatter(columns[3],columns[-1])
# Out:
#                          80.0,10.0,10.0,50  50.0,0.0,50.0,50  \
# test_string_accuracy                   1.0          0.990722
# test_character_accuracy                1.0          0.996741
# test_evaluated_accuracy                1.0          0.996741
#
#                          25.0,0.0,75.0,75  10.0,0.0,90.0,100  true
# test_string_accuracy             0.838222           0.322000   1.0
# test_character_accuracy          0.942222           0.739685   1.0
# test_evaluated_accuracy          0.942222           0.739685   1.0

# %%
#%%

# df.plot.scatter(columns[0],columns[-1])

# %%
#%%

# symbol by symbol
wrong_positions = [np.argwhere(np.array(p)!=trues) for p in preds]
# visualize the differences perhaps scatterplot
#find out what kind of mistakes your models make on the misclassified samples.
wrong_data = [X_test[pos] for pos in wrong_positions]

# decoded_wrong_inputs = [[list(map(decode_labels,data)) for data in model_wrong_data] for model_wrong_data in wrong_data]
wrong_outputs = [np.array(p)[idx] for idx,p in zip(wrong_positions,preds)]
wrong_out_characters = ["".join([str(i) for i in w.ravel()]) for w in wrong_outputs]
correct_characters = ["".join([str(i) for i in np.array(trues)[idx].ravel()]) for idx in wrong_positions ]

pred_characters = ["".join([str(i) for i in y]) for y in preds]
true_characters = "".join([str(char) for y in trues for char in y])
mapping = {i:n for i,n in zip(unique_characters,range(len(unique_characters)))}

counts = [Counter([(true,pred) for true,pred in zip(true_characters,chars)]) for chars in pred_characters]


fig, ax = plt.subplots(2, 2, figsize=(25, 20))
for i in range(len(models)):
    # Compute confusion matrix
    cm = confusion_matrix(list(true_characters), list(pred_characters[i]))
    
    g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
    g.set_xticklabels(['ws', 'neg'] + list('0123456789'))
    g.set_yticklabels(['ws', 'neg'] + list('0123456789'))
    ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
    ax[int(i/2)][i%2].set_xlabel('Predicted')
    ax[int(i/2)][i%2].set_ylabel('True')

plt.show()
