# %% [markdown]
# # %% [markdown]
#
#  # Function definitions for creating the datasets
#
#  First we need to create our datasets that are going to be used for training our models.
#
#  In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library.
#  We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
# %%

import matplotlib.pyplot as plt
import cv2

import numpy as np
import pandas as pd

import tensorflow.keras as keras # type: ignore
from tensorflow.keras.layers import Dense, LSTM, TimeDistributed # type: ignore
from tensorflow.keras.layers import RepeatVector # type: ignore


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from collections import Counter
from sklearn.metrics import confusion_matrix
from matplotlib.colors import LogNorm
import seaborn as sns
# Out:
# 2024-12-13 22:44:23.094688: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-13 22:44:23.116420: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-13 22:44:23.116438: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-13 22:44:23.117149: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-13 22:44:23.120820: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-13 22:44:25.318320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %%

from scipy.ndimage import rotate


np.random.seed(42)

# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images


def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())

# %%
# %%

def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:
    
    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=False)
                query_image = []

                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=False)
                result_image = []
                
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())
                    
                X_text.append(query_string)
                X_img.append(np.stack(query_image))

                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '

    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
# # %% [markdown]
#
#  # Creating our data
#
#  The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#    **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#    **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#    **y_text**: strings containing answers of length 3: ['  2', '156']
#    **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# %%

# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
        
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(2):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #6745
#
# X_text: "33-72" = y_text: "-39"
# ==================================================
# Query #2107
#
# X_text: "10-53" = y_text: "-43"

# %% [markdown]
# # %% [markdown]
#
#  ## Helper functions
#
#
#
#  The functions below will help with input/output of the data.

# %%
# %%

# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs

# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot

def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])
    
    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
# # %% [markdown]
#
#  ---
#
#  ## I. Text-to-text RNN model
#
#  The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
#  1. LSTM
#
#  2. TimeDistributed
#
#  3. RepeatVector
#
#  The code cell below explains each of these new components.
#
#  <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
# %%

def build_text2text_model():
    # We start by initializing a sequential model
    text2text = keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. 
    # Each of these 5 elements in the query will be fed to the network one by one, as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. 
    # Repeat 3 times as that's the maximum length of the output (e.g. ' 1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). 
    # This is necessary as TimeDistributed in the below expects the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True)) 

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

def build_text2text_model_additional_lstm():
    text2text = keras.Sequential()
    text2text.add(LSTM(128, input_shape=(None, len(unique_characters)), return_sequences=True))
    text2text.add(LSTM(128))
    text2text.add(RepeatVector(max_answer_length))
    text2text.add(LSTM(256, return_sequences=True)) 
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()
    return text2text

# %%
# %%

## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)

data_percentage = [
    [80.0, 10.0, 10.0, 50], 
    [50.0, 0.0, 50.0, 50], 
    [25.0, 0.0, 75.0, 75], 
    [10.0, 0.0, 90.0, 100]
]
models=[]
for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, 
                                                        random_state=42) 

    # Fit the model
    model = build_text2text_model()
    # model = build_text2text_model_additional_lstm()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), 
                                                            random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',         # metric to monitor
            patience=10,                # number of epochs to wait for improvement
            restore_best_weights=True   # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")
    plt.title(f"{each[0]}, {each[1]}, {each[2]}")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Result for TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    print("Train Accuracy for text to text model: ", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model: ", model.evaluate(X_test, y_test))
    print("Test String Accuracy: ", accuracy)

    #to clear cache
    models.append(model)
    continue
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 2024-12-13 22:44:33.589027: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.614337: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.614435: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.615443: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.615509: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.615557: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.664580: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.664671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.664727: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-13 22:44:33.664770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6224 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-12-13 22:44:33.741142: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-12-13 22:44:33.741164: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2024-12-13 22:44:33.741222: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               276480
#
#  repeat_vector (RepeatVecto  (None, 3, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed (TimeDist  (None, 3, 13)             3341
#  ributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 2024-12-13 22:44:34.867380: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-12-13 22:44:34.915285: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984601: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984624: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984642: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984671: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984718: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984733: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.984750: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:34.985209: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.110877: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.110892: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.112435: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.112444: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.112651: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.113188: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.115870: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.116433: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.211276: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.245443: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.330115: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.330245: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.330291: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.330316: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.330670: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.331034: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.333962: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.334435: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.335100: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:44:35.521471: I external/local_xla/xla/service/service.cc:168] XLA service 0x755fa2d3f500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-13 22:44:35.521487: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2024-12-13 22:44:35.524183: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#  23/500 [>.............................] - ETA: 1s - loss: 2.4651 - accuracy: 0.2210
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734126275.561756 2679856 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 500/500 [==============================] - 5s 7ms/step - loss: 1.7147 - accuracy: 0.3433 - val_loss: 1.4653 - val_accuracy: 0.4222
# Epoch 2/50
# 500/500 [==============================] - 2s 5ms/step - loss: 1.2928 - accuracy: 0.4928 - val_loss: 1.1125 - val_accuracy: 0.5775
# Epoch 3/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.1057 - accuracy: 0.5653 - val_loss: 1.0737 - val_accuracy: 0.5670
# Epoch 4/50
# 500/500 [==============================] - 3s 5ms/step - loss: 1.0096 - accuracy: 0.6058 - val_loss: 0.9988 - val_accuracy: 0.6113
# Epoch 5/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.
50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0071 - accuracy: 0.9993 - val_loss: 0.0036 - val_accuracy: 0.9998
# Epoch 35/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0513 - accuracy: 0.9832 - val_loss: 0.1135 - val_accuracy: 0.9572
# Epoch 36/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0033 - val_accuracy: 0.9998
# Epoch 37/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.0544 - val_accuracy: 0.9802
# Epoch 38/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.0047 - val_accuracy: 0.9995
# Epoch 39/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 40/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 41/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 8.7497e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 43/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1031 - accuracy: 0.9720 - val_loss: 0.0138 - val_accuracy: 0.9980
# Epoch 44/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0054 - val_accuracy: 0.9998
# Epoch 45/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 46/50
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9998
# Epoch 47/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9998
# Epoch 48/50
# 500/500 [==============================] - 2s 4ms/step - loss: 9.1238e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 0.9998
# Epoch 49/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.0502 - accuracy: 0.9881 - val_loss: 0.8518 - val_accuracy: 0.7630
# Epoch 50/50
# 500/500 [==============================] - 3s 5ms/step - loss: 0.0588 - accuracy: 0.9826 - val_loss: 0.0072 - val_accuracy: 0.9987
# 63/63 [==============================] - 0s 1ms/step
# Result for TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9995
# Train Accuracy for text to text model:  [0.004837339278310537, 0.9995208382606506]
# 63/63 [==============================] - 0s 725us/step - loss: 0.0056 - accuracy: 0.9995
# Test Accuracy for text to text model:  [0.005607647821307182, 0.9994999766349792]
# Test String Accuracy:  0.9985
# TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 256)               276480
#
#  repeat_vector_1 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_3 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed_1 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
#   1/313 [..............................] - ETA: 5:08 - loss: 2.5644 - accuracy: 0.0625
# 2024-12-13 22:46:34.869776: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:46:34.869792: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:46:34.871246: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:46:34.882616: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:46:34.882637: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-12-13 22:46:34.882653: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 310/313 [============================>.] - ETA: 0s - loss: 1.7940 - accuracy: 0.3132WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 4ms/step - loss: 1.7929 - accuracy: 0.3136
# Epoch 2/50
# 307/313 [============================>.] - ETA: 0s - loss: 1.5159 - accuracy: 0.4069WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 4ms/step - loss: 1.5129 - accuracy: 0.4081
# Epoch 3/50
# 310/313 [============================>.] - ETA: 0s - loss: 1.2695 - accuracy: 0.5041WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 5ms/step - loss: 1.2691 - accuracy: 0.5042
# Epoch 4/50
# 311/313 [============================>.] - ETA: 0s - loss: 1.1395 - accuracy: 0.5550WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1393 - accuracy: 0.5550
# Epoch 5/50
# 309/313 [============================>.] - ETA: 0s - loss: 1.0643 - accuracy: 0.5837WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 5ms/step - loss: 1.0650 - accuracy: 0.5835
# Epoch 6/50
# 311/313 [============================>.] - ETA: 0s - loss: 1.0224 - accuracy: 0.5959WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0222 - accuracy: 0.5962
# Epoch 7/50
# 308/313 [============================>.] - ETA: 0s - loss: 0.9824 - accuracy: 0.6161WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9823 - accuracy: 0.6158
# Epoch 8/50
# 310/313 [============================>.] - ETA: 0s - loss: 0.9618 - accuracy: 0.6233WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9615 - accuracy: 0.6233
# Epoch 9/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.9424 - accuracy: 0.6335WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9424 - accuracy: 0.6335
# Epoch 10/50
# 307/313 [============================>.] - ETA: 0s - loss: 0
100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9489WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9490
# Epoch 77/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1777 - accuracy: 0.9630WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1792 - accuracy: 0.9622
# Epoch 78/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.1729 - accuracy: 0.9604WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1744 - accuracy: 0.9592
# Epoch 79/100
# 42/63 [===================>..........] - ETA: 0s - loss: 0.1623 - accuracy: 0.9658WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.9600
# Epoch 80/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1757 - accuracy: 0.9563WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9568
# Epoch 81/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1570 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1593 - accuracy: 0.9640
# Epoch 82/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1568 - accuracy: 0.9637WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1566 - accuracy: 0.9643
# Epoch 83/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1279 - accuracy: 0.9778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9772
# Epoch 84/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9672WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9675
# Epoch 85/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1182 - accuracy: 0.9773WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1206 - accuracy: 0.9772
# Epoch 86/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9640WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1471 - accuracy: 0.9637
# Epoch 87/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.2179 - accuracy: 0.9306WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.2159 - accuracy: 0.9315
# Epoch 88/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.1373 - accuracy: 0.9706WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1362 - accuracy: 0.9707
# Epoch 89/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1249 - accuracy: 0.9713WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1245 - accuracy: 0.9713
# Epoch 90/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9664WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.1342 - accuracy: 0.9663
# Epoch 91/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1259 - accuracy: 0.9674WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9673
# Epoch 92/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0851 - accuracy: 0.9880WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0857 - accuracy: 0.9875
# Epoch 93/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9918WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.9918
# Epoch 94/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9938WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0663 - accuracy: 0.9938
# Epoch 95/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0643 - accuracy: 0.9957WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0641 - accuracy: 0.9957
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9947WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.9947
# Epoch 97/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0521 - accuracy: 0.9957WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0527 - accuracy: 0.9955
# Epoch 98/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0488 - accuracy: 0.9976WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9977
# Epoch 99/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.0457 - accuracy: 0.9973WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9977
# Epoch 100/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.0414 - accuracy: 0.9975WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9978
# 563/563 [==============================] - 1s 619us/step
# Result for TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# 63/63 [==============================] - 0s 947us/step - loss: 0.0364 - accuracy: 0.9987
# Train Accuracy for text to text model:  [0.036361776292324066, 0.9986666440963745]
# 563/563 [==============================] - 0s 768us/step - loss: 0.4112 - accuracy: 0.8688
# Test Accuracy for text to text model:  [0.41121551394462585, 0.8687777519226074]
# Test String Accuracy:  0.6541111111111111

# %%
#%%

# check that we get correct results -> done
preds = [list(map(decode_labels,m.predict(X_test))) for m in models]
trues = list(map(decode_labels,y_test))
scores = [accuracy_score(trues,i) for i in preds+[trues]]
scores_chars = [accuracy_score(list("".join(trues)), list("".join(i))) for i in preds+[trues]]
evals = [m.evaluate(X_test,y_test)[1] for m in models] + [1]
# Out:
# 563/563 [==============================] - 1s 2ms/step
# 563/563 [==============================] - 0s 687us/step
# 563/563 [==============================] - 0s 580us/step
# 563/563 [==============================] - 0s 693us/step
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9994
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1034 - accuracy: 0.9680
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0336 - accuracy: 0.9902
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4112 - accuracy: 0.8688

# %%
#%%

l = []
columns = [",".join([str(i) for i in l]) for l in data_percentage]
for model_preds in preds:
    # fig, ax = plt.subplots(2, 2, figsize=(25, 20))
    for i in range(3):
        pos_pred = [p[i] for p in model_preds]
        pos_true = [t[i] for t in trues]
        cm = confusion_matrix(pos_pred,pos_true)
        # print(pos,":",sns.heatmap(pos_pred,pos_true))

        # g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
        # ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
        # ax[int(i/2)][i%2].set_xlabel('Predicted')
        # ax[int(i/2)][i%2].set_ylabel('True')
        mistakes = (1-accuracy_score(pos_true,pos_pred))*len(pos_pred)
        l.append(int(mistakes+0.1))
mistakes = pd.DataFrame(np.array(l).reshape(4,-1))
mistakes.index = columns
mistakes.columns = ["100s position","10s position","1s position"]
mistakes.plot.bar(log=True,rot=8,cmap="coolwarm")
plt.savefig('mistakes.png')

# %%
#%%

# when do we get a decreased accuracy and why
# entire output numbers
columns = [",".join([str(i) for i in l]) for l in data_percentage] + ['true']
score_df = pd.DataFrame([scores,scores_chars, evals])
score_df.index=["test_string_accuracy","test_character_accuracy","test_evaluated_accuracy"]
score_df.columns = columns
df = pd.DataFrame(preds+[trues]).T
df.columns = columns
# df.plot.scatter(columns[1],columns[-1])
# df.plot.scatter(columns[2],columns[-1])
# df.plot.scatter(columns[3],columns[-1])

# %%
#%%

# df.plot.scatter(columns[0],columns[-1])

# %%
#%%

# symbol by symbol
wrong_positions = [np.argwhere(np.array(p)!=trues) for p in preds]
# visualize the differences perhaps scatterplot
#find out what kind of mistakes your models make on the misclassified samples.
wrong_data = [X_test[pos] for pos in wrong_positions]

# decoded_wrong_inputs = [[list(map(decode_labels,data)) for data in model_wrong_data] for model_wrong_data in wrong_data]
wrong_outputs = [np.array(p)[idx] for idx,p in zip(wrong_positions,preds)]
wrong_out_characters = ["".join([str(i) for i in w.ravel()]) for w in wrong_outputs]
correct_characters = ["".join([str(i) for i in np.array(trues)[idx].ravel()]) for idx in wrong_positions ]

pred_characters = ["".join([str(i) for i in y]) for y in preds]
true_characters = "".join([str(char) for y in trues for char in y])
mapping = {i:n for i,n in zip(unique_characters,range(len(unique_characters)))}

counts = [Counter([(true,pred) for true,pred in zip(true_characters,chars)]) for chars in pred_characters]


fig, ax = plt.subplots(2, 2, figsize=(25, 20))
for i in range(len(models)):
    # Compute confusion matrix
    cm = confusion_matrix(list(true_characters), list(pred_characters[i]))
    
    g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
    g.set_xticklabels(['ws', 'neg'] + list('0123456789'))
    g.set_yticklabels(['ws', 'neg'] + list('0123456789'))
    ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
    ax[int(i/2)][i%2].set_xlabel('Predicted')
    ax[int(i/2)][i%2].set_ylabel('True')

plt.show()

# %%
# %%

## Your code (look at the assignment description for your tasks for text-to-text model):
##( Your first task is to fit the text2text model using X_text and y_text)

data_percentage = [
    [80.0, 10.0, 10.0, 50], 
    [50.0, 0.0, 50.0, 50], 
    [25.0, 0.0, 75.0, 75], 
    [10.0, 0.0, 90.0, 100]
]
models=[]
for each in data_percentage:
    print("TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, 
                                                        test_size=(each[1]+each[2])/100.0, 
                                                        random_state=42) 

    # Fit the model
    model = build_text2text_model_additional_lstm()
    # model = build_text2text_model_additional_lstm()
    checkpoint_cb = keras.callbacks.ModelCheckpoint(
            f"text_to_text_best.keras", save_best_only=True
        )
    
    if each[1]:
        X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                            test_size=each[1]/(each[1]+each[2]), 
                                                            random_state=42) 
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',         # metric to monitor
            patience=10,                # number of epochs to wait for improvement
            restore_best_weights=True   # restore the best weights after stopping
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_valid, y_valid),
            batch_size=32,
            epochs=50,
            callbacks=[checkpoint_cb, early_stopping],
        )
    else:
        history = model.fit(
            X_train,
            y_train,
            batch_size=32,
            epochs=each[-1],
            callbacks=[checkpoint_cb]
        )
    
    plt.plot(history.history['loss'], label='loss')
    if each[1]:
        plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('epochs')
    plt.ylabel('score')
    plt.legend(loc="best")
    plt.title(f"{each[0]}, {each[1]}, {each[2]}")

    plt.grid(True)
    plt.tight_layout()
    plt.show()

    predictions = model.predict(X_test)
    y_pred = [decode_labels(y) for y in predictions]
    y_actual = [decode_labels(y) for y in y_test]

    accuracy = accuracy_score(y_actual, y_pred)
    print("Result for TRAIN, VALID, TEST Percentage", each[0], each[1], each[2])
    print("Train Accuracy for text to text model: ", model.evaluate(X_train, y_train))
    print("Test Accuracy for text to text model: ", model.evaluate(X_test, y_test))
    print("Test String Accuracy: ", accuracy)

    #to clear cache
    models.append(model)
    continue
    import gc

    # Delete unnecessary variables
    del model

    # Force garbage collection
    gc.collect()
# Out:
# TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, None, 128)         72704
#
#  lstm_9 (LSTM)               (None, 128)               131584
#
#  repeat_vector_4 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_10 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_4 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 4s 6ms/step - loss: 1.7396 - accuracy: 0.3286 - val_loss: 1.5401 - val_accuracy: 0.4008
# Epoch 2/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.4303 - accuracy: 0.4394 - val_loss: 1.2597 - val_accuracy: 0.4853
# Epoch 3/50
# 500/500 [==============================] - 3s 6ms/step - loss: 1.1444 - accuracy: 0.5492 - val_loss: 1.0661 - val_accuracy: 0.5737
# Epoch 4/50
# 500/500 [==============================] - 3s 7ms/step - loss: 1.0479 - accuracy: 0.5857 - val_loss: 0.9931 - val_accuracy: 0.6085
# Epoch 5/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.9793 - accuracy: 0.6153 - val_loss: 0.9522 - val_accuracy: 0.6218
# Epoch 6/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.9524 - accuracy: 0.6247 - val_loss: 0.8926 - val_accuracy: 0.6590
# Epoch 7/50
# 500/500 [==============================] - 3s 6ms/step - loss: 0.9248 - accuracy: 0.6392 - val_loss: 0.8924 - val_accuracy: 0.6578
# Epoch 8/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0
50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9998
# Epoch 41/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9997
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9998
# Epoch 43/50
# 500/500 [==============================] - 1s 2ms/step - loss: 9.4672e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 0.9998
# Epoch 44/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.1203 - accuracy: 0.9689 - val_loss: 0.0062 - val_accuracy: 0.9997
# Epoch 45/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.0144 - val_accuracy: 0.9965
# Epoch 46/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.9872 - val_loss: 0.0826 - val_accuracy: 0.9762
# Epoch 47/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0052 - val_accuracy: 0.9992
# Epoch 48/50
# 500/500 [==============================] - 2s 4ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0021 - val_accuracy: 0.9998
# Epoch 49/50
# 500/500 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9998
# Epoch 50/50
# 500/500 [==============================] - 3s 5ms/step - loss: 8.6577e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9998
# 63/63 [==============================] - 0s 1ms/step
# Result for TRAIN, VALID, TEST Percentage 80.0 10.0 10.0
# 500/500 [==============================] - 0s 901us/step - loss: 7.5420e-04 - accuracy: 1.0000
# Train Accuracy for text to text model:  [0.0007541979430243373, 1.0]
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Test Accuracy for text to text model:  [0.0011150508653372526, 1.0]
# Test String Accuracy:  1.0
# TRAIN, VALID, TEST Percentage 50.0 0.0 50.0
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, None, 128)         72704
#
#  lstm_12 (LSTM)              (None, 128)               131584
#
#  repeat_vector_5 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_13 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_5 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 291/313 [==========================>...] - ETA: 0s - loss: 1.8308 - accuracy: 0.3042WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 3s 5ms/step - loss: 1.8199 - accuracy: 0.3073
# Epoch 2/50
# 311/313 [============================>.] - ETA: 0s - loss: 1.5932 - accuracy: 0.3800WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 1.5929 - accuracy: 0.3801
# Epoch 3/50
# 305/313 [============================>.] - ETA: 0s - loss: 1.4362 - accuracy: 0.4351WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 5ms/step - loss: 1.4346 - accuracy: 0.4354
# Epoch 4/50
# 306/313 [============================>.] - ETA: 0s - loss: 1.2158 - accuracy: 0.5220WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 1.2136 - accuracy: 0.5232
# Epoch 5/50
# 308/313 [============================>.] - ETA: 0s - loss: 1.0985 - accuracy: 0.5682WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0983 - accuracy: 0.5680
# Epoch 6/50
# 306/313 [============================>.] - ETA: 0s - loss: 1.0359 - accuracy: 0.5950WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 8ms/step - loss: 1.0355 - accuracy: 0.5953
# Epoch 7/50
# 308/313 [============================>.] - ETA: 0s - loss: 1.0025 - accuracy: 0.6083WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0018 - accuracy: 0.6088
# Epoch 8/50
# 312/313 [============================>.] - ETA: 0s - loss: 0.9573 - accuracy: 0.6292WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9573 - accuracy: 0.6291
# Epoch 9/50
# 289/313 [==========================>...] - ETA: 0s - loss: 0.9458 - accuracy: 0.6313WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9457 - accuracy: 0.6309
# Epoch 10/50
# 299/313 [===========================>..] - ETA: 0s - loss: 0.9148 - accuracy: 0.6465WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9155 - accuracy: 0.6463
# Epoch 11/50
# 311/313 [============================>.] - ETA: 0s - loss: 0.9103 - accuracy: 0.6472WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9102 - accuracy: 0.6472
# Epoch 12/50
# 305/313 [============================>.] - ETA: 0s - loss: 0.8962 - accuracy: 0.6532WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8962 - accuracy: 0.6530
# Epoch 13/50
# 309/313 [============================>.] - ETA: 0s - loss: 0.8753 - accuracy: 0.6625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 6ms/step - loss: 0.8757 - accuracy: 0.6623
# Epoch 14/50
# 307/313 [============================>.] - ETA: 0s - loss: 0.8643 - accuracy: 0.6679WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 2s 7ms/step - loss: 0.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0373 - accuracy: 0.9880
# Test Accuracy for text to text model:  [0.03729594871401787, 0.9879999756813049]
# Test String Accuracy:  0.9675
# TRAIN, VALID, TEST Percentage 25.0 0.0 75.0
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, None, 128)         72704
#
#  lstm_15 (LSTM)              (None, 128)               131584
#
#  repeat_vector_6 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_16 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_6 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 151/157 [===========================>..] - ETA: 0s - loss: 1.9601 - accuracy: 0.2773WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 3s 6ms/step - loss: 1.9528 - accuracy: 0.2781
# Epoch 2/75
# 156/157 [============================>.] - ETA: 0s - loss: 1.6990 - accuracy: 0.3334WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 5ms/step - loss: 1.6991 - accuracy: 0.3333
# Epoch 3/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.6375 - accuracy: 0.3626WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 1.6366 - accuracy: 0.3628
# Epoch 4/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.5318 - accuracy: 0.3998WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 1.5306 - accuracy: 0.3998
# Epoch 5/75
# 149/157 [===========================>..] - ETA: 0s - loss: 1.4267 - accuracy: 0.4376WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 5ms/step - loss: 1.4244 - accuracy: 0.4385
# Epoch 6/75
# 150/157 [===========================>..] - ETA: 0s - loss: 1.2925 - accuracy: 0.4872WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2906 - accuracy: 0.4881
# Epoch 7/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.2096 - accuracy: 0.5173WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2088 - accuracy: 0.5176
# Epoch 8/75
# 157/157 [==============================] - ETA: 0s - loss: 1.1308 - accuracy: 0.5609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 1.1308 - accuracy: 0.5609
# Epoch 9/75
# 144/157 [==========================>...] - ETA: 0s - loss: 1.0942 - accuracy: 0.5744WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 0s 2ms/step - loss: 1.0912 - accuracy: 0.5749
# Epoch 10/75
# 152/157 [============================>.] - ETA: 0s - loss: 1.0527 - accuracy: 0.5857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 3ms/step - loss: 1.0531 - accuracy: 0.5857
# Epoch 11/75
# 152/157 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.6076WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 1.0144 - accuracy: 0.6087
# Epoch 12/75
# 154/157 [============================>.] - ETA: 0s - loss: 1.0065 - accuracy: 0.6074WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0059 - accuracy: 0.6074
# Epoch 13/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.9811 - accuracy: 0.6157WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.9816 - accuracy: 0.6150
# Epoch 14/75
# 145/157 [==========================>...] - ETA: 0s - loss: 0.9895 - accuracy: 0.6079WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.9883 - accuracy: 0.6083
# Epoch 15/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.9492 - accuracy: 0.6345WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.9500 - accuracy: 0.6338
# Epoch 16/75
# 145/157 [==========================>...] - ETA: 0s - loss: 0.9428 - accuracy: 0.6360WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 0s 3ms/step - loss: 0.9414 - accuracy: 0.6359
# Epoch 17/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.9259 - accuracy: 0.6418WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.9265 - accuracy: 0.6415
# Epoch 18/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.9370 - accuracy: 0.6397WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9365 - accuracy: 0.6391
# Epoch 19/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.9132 - accuracy: 0.6481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9123 - accuracy: 0.6486
# Epoch 20/75
# 157/157 [==============================] - ETA: 0s - loss: 0.9242 - accuracy: 0.6405WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.9242 - accuracy: 0.6405
# Epoch 21/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.8959 - accuracy: 0.6578WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.
ARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.1794 - accuracy: 0.9539
# Epoch 54/75
# 141/157 [=========================>....] - ETA: 0s - loss: 0.1826 - accuracy: 0.9484WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.1874 - accuracy: 0.9448
# Epoch 55/75
# 151/157 [===========================>..] - ETA: 0s - loss: 0.1579 - accuracy: 0.9592WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.1591 - accuracy: 0.9587
# Epoch 56/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1375 - accuracy: 0.9653
# Epoch 57/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9592WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 6ms/step - loss: 0.1452 - accuracy: 0.9590
# Epoch 58/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.1589 - accuracy: 0.9501WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.1587 - accuracy: 0.9503
# Epoch 59/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9752WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.1037 - accuracy: 0.9753
# Epoch 60/75
# 151/157 [===========================>..] - ETA: 0s - loss: 0.1021 - accuracy: 0.9748WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1028 - accuracy: 0.9743
# Epoch 61/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.1335 - accuracy: 0.9597WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.1332 - accuracy: 0.9596
# Epoch 62/75
# 151/157 [===========================>..] - ETA: 0s - loss: 0.1109 - accuracy: 0.9685WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1091 - accuracy: 0.9692
# Epoch 63/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9795WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0806 - accuracy: 0.9795
# Epoch 64/75
# 157/157 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9809WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0748 - accuracy: 0.9809
# Epoch 65/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0679 - accuracy: 0.9837
# Epoch 66/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9917WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0478 - accuracy: 0.9916
# Epoch 67/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0779 - accuracy: 0.9767
# Epoch 68/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0783 - accuracy: 0.9770WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0782 - accuracy: 0.9770
# Epoch 69/75
# 154/157 [============================>.] - ETA: 0s - loss: 0.0880 - accuracy: 0.9723WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0878 - accuracy: 0.9723
# Epoch 70/75
# 147/157 [===========================>..] - ETA: 0s - loss: 0.0577 - accuracy: 0.9856WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0566 - accuracy: 0.9860
# Epoch 71/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9931WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0359 - accuracy: 0.9927
# Epoch 72/75
# 155/157 [============================>.] - ETA: 0s - loss: 0.0694 - accuracy: 0.9787WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0692 - accuracy: 0.9788
# Epoch 73/75
# 153/157 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1153 - accuracy: 0.9657
# Epoch 74/75
# 156/157 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9861WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0507 - accuracy: 0.9861
# Epoch 75/75
# 152/157 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0595 - accuracy: 0.9818
# 469/469 [==============================] - 1s 685us/step
# Result for TRAIN, VALID, TEST Percentage 25.0 0.0 75.0
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0378 - accuracy: 0.9911
# Train Accuracy for text to text model:  [0.037830933928489685, 0.9910666942596436]
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0784 - accuracy: 0.9742
# Test Accuracy for text to text model:  [0.07838677614927292, 0.9741777777671814]
# Test String Accuracy:  0.9251333333333334
# TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None, None, 128)         72704
#
#  lstm_18 (LSTM)              (None, 128)               131584
#
#  repeat_vector_7 (RepeatVec  (None, 3, 128)            0
#  tor)
#
#  lstm_19 (LSTM)              (None, 3, 256)            394240
#
#  time_distributed_7 (TimeDi  (None, 3, 13)             3341
#  stributed)
#
# =================================================================
# Total params: 601869 (2.30 MB)
# Trainable params: 601869 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 60/63 [===========================>..] - ETA: 0s - loss: 2.2209 - accuracy: 0.2175WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 2s 7ms/step - loss: 2.2103 - accuracy: 0.2197
# Epoch 2/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.8113 - accuracy: 0.2873WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 1.8035 - accuracy: 0.2933
# Epoch 3/100
# 61/63 [============================>.] - ETA: 0s - loss: 1.7250 - accuracy: 0.3195WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 1.7250 - accuracy: 0.3200
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 1.7003 - accuracy: 0.3302WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 1.7003 - accuracy: 0.3302
# Epoch 5/100
# 57/63 [==========================>...] - ETA: 0s - loss: 1.6801 - accuracy: 0.3436WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# 63/63 [==============================] - 0s 8ms/step - loss: 0.9143 - accuracy: 0.6505
# Epoch 42/100
# 62/63 [============================>.] - ETA: 0s - loss: 0
100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.6357 - accuracy: 0.7723WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.6387 - accuracy: 0.7715
# Epoch 76/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.6432 - accuracy: 0.7590WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6448 - accuracy: 0.7610
# Epoch 77/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.6476 - accuracy: 0.7613WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6461 - accuracy: 0.7615
# Epoch 78/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.6415 - accuracy: 0.7696WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6384 - accuracy: 0.7707
# Epoch 79/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.6193 - accuracy: 0.7723WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6203 - accuracy: 0.7702
# Epoch 80/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.6104 - accuracy: 0.7766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6105 - accuracy: 0.7763
# Epoch 81/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.5863 - accuracy: 0.7895WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5833 - accuracy: 0.7898
# Epoch 82/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.5558 - accuracy: 0.8023WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5615 - accuracy: 0.7983
# Epoch 83/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.6199 - accuracy: 0.7786WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6202 - accuracy: 0.7778
# Epoch 84/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.5646 - accuracy: 0.7957WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5636 - accuracy: 0.7962
# Epoch 85/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.5590 - accuracy: 0.8009WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5582 - accuracy: 0.8013
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 0.5328 - accuracy: 0.8067WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5328 - accuracy: 0.8067
# Epoch 87/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.5427 - accuracy: 0.8031WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5431 - accuracy: 0.8037
# Epoch 88/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.5311 - accuracy: 0.8056WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5314 - accuracy: 0.8053
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.8202WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.4968 - accuracy: 0.8202
# Epoch 90/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.5116 - accuracy: 0.8130WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5116 - accuracy: 0.8143
# Epoch 91/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4756 - accuracy: 0.8328WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4747 - accuracy: 0.8332
# Epoch 92/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.4609 - accuracy: 0.8344WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4621 - accuracy: 0.8352
# Epoch 93/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.4639 - accuracy: 0.8342WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.4675 - accuracy: 0.8322
# Epoch 94/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.5050 - accuracy: 0.8208WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 8ms/step - loss: 0.5063 - accuracy: 0.8207
# Epoch 95/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.4695 - accuracy: 0.8323WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4679 - accuracy: 0.8333
# Epoch 96/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.4099 - accuracy: 0.8626WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4140 - accuracy: 0.8593
# Epoch 97/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.4201 - accuracy: 0.8517WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4222 - accuracy: 0.8507
# Epoch 98/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.3828 - accuracy: 0.8697WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3825 - accuracy: 0.8697
# Epoch 99/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.3692 - accuracy: 0.8748WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 4ms/step - loss: 0.3706 - accuracy: 0.8740
# Epoch 100/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.3796 - accuracy: 0.8656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3786 - accuracy: 0.8660
# 563/563 [==============================] - 2s 2ms/step
# Result for TRAIN, VALID, TEST Percentage 10.0 0.0 90.0
# 63/63 [==============================] - 1s 3ms/step - loss: 0.3450 - accuracy: 0.8890
# Train Accuracy for text to text model:  [0.34504151344299316, 0.8889999985694885]
# 563/563 [==============================] - 2s 4ms/step - loss: 0.7207 - accuracy: 0.7474
# Test Accuracy for text to text model:  [0.7207258343696594, 0.74742591381073]
# Test String Accuracy:  0.3297777777777778

# %%
#%%

# check that we get correct results -> done
preds = [list(map(decode_labels,m.predict(X_test))) for m in models]
trues = list(map(decode_labels,y_test))
scores = [accuracy_score(trues,i) for i in preds+[trues]]
scores_chars = [accuracy_score(list("".join(trues)), list("".join(i))) for i in preds+[trues]]
evals = [m.evaluate(X_test,y_test)[1] for m in models] + [1]
# Out:
# 563/563 [==============================] - 1s 3ms/step
# 563/563 [==============================] - 0s 733us/step
# 563/563 [==============================] - 0s 661us/step
# 563/563 [==============================] - 0s 675us/step
# 563/563 [==============================] - 1s 2ms/step - loss: 8.5511e-04 - accuracy: 1.0000
# 563/563 [==============================] - 1s 1ms/step - loss: 0.0356 - accuracy: 0.9891
# 563/563 [==============================] - 1s 2ms/step - loss: 0.0716 - accuracy: 0.9770
# 563/563 [==============================] - 1s 2ms/step - loss: 0.7207 - accuracy: 0.7474

# %%
#%%

l = []
columns = [",".join([str(i) for i in l]) for l in data_percentage]
for model_preds in preds:
    # fig, ax = plt.subplots(2, 2, figsize=(25, 20))
    for i in range(3):
        pos_pred = [p[i] for p in model_preds]
        pos_true = [t[i] for t in trues]
        cm = confusion_matrix(pos_pred,pos_true)
        # print(pos,":",sns.heatmap(pos_pred,pos_true))

        # g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
        # ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
        # ax[int(i/2)][i%2].set_xlabel('Predicted')
        # ax[int(i/2)][i%2].set_ylabel('True')
        mistakes = (1-accuracy_score(pos_true,pos_pred))*len(pos_pred)
        l.append(int(mistakes+0.1))
mistakes = pd.DataFrame(np.array(l).reshape(4,-1))
mistakes.index = columns
mistakes.columns = ["100s position","10s position","1s position"]
mistakes.plot.bar(log=True,rot=8,cmap="coolwarm")
plt.savefig('mistakes.png')

# %%
#%%

# when do we get a decreased accuracy and why
# entire output numbers
columns = [",".join([str(i) for i in l]) for l in data_percentage] + ['true']
score_df = pd.DataFrame([scores,scores_chars, evals])
score_df.index=["test_string_accuracy","test_character_accuracy","test_evaluated_accuracy"]
score_df.columns = columns
df = pd.DataFrame(preds+[trues]).T
df.columns = columns
# df.plot.scatter(columns[1],columns[-1])
# df.plot.scatter(columns[2],columns[-1])
# df.plot.scatter(columns[3],columns[-1])

# %%
#%%

# df.plot.scatter(columns[0],columns[-1])

# %%
#%%

# symbol by symbol
wrong_positions = [np.argwhere(np.array(p)!=trues) for p in preds]
# visualize the differences perhaps scatterplot
#find out what kind of mistakes your models make on the misclassified samples.
wrong_data = [X_test[pos] for pos in wrong_positions]

# decoded_wrong_inputs = [[list(map(decode_labels,data)) for data in model_wrong_data] for model_wrong_data in wrong_data]
wrong_outputs = [np.array(p)[idx] for idx,p in zip(wrong_positions,preds)]
wrong_out_characters = ["".join([str(i) for i in w.ravel()]) for w in wrong_outputs]
correct_characters = ["".join([str(i) for i in np.array(trues)[idx].ravel()]) for idx in wrong_positions ]

pred_characters = ["".join([str(i) for i in y]) for y in preds]
true_characters = "".join([str(char) for y in trues for char in y])
mapping = {i:n for i,n in zip(unique_characters,range(len(unique_characters)))}

counts = [Counter([(true,pred) for true,pred in zip(true_characters,chars)]) for chars in pred_characters]


fig, ax = plt.subplots(2, 2, figsize=(25, 20))
for i in range(len(models)):
    # Compute confusion matrix
    cm = confusion_matrix(list(true_characters), list(pred_characters[i]))
    
    g = sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', ax=ax[int(i/2)][i%2], norm=LogNorm(), cbar=False)
    g.set_xticklabels(['ws', 'neg'] + list('0123456789'))
    g.set_yticklabels(['ws', 'neg'] + list('0123456789'))
    ax[int(i/2)][i%2].set_title('Confusion Matrix(in %)')
    ax[int(i/2)][i%2].set_xlabel('Predicted')
    ax[int(i/2)][i%2].set_ylabel('True')

plt.show()
